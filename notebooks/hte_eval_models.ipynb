# %%
# !nvidia-smi
# Out:
# Sun Oct 13 12:09:14 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.14              Driver Version: 550.54.14      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:0E:00.0 Off |                    0 |
# | N/A   50C    P0            321W /  400W |   69299MiB /  81920MiB |    100%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA A100-SXM4-80GB          Off |   00000000:13:00.0 Off |                    0 |
# | N/A   31C    P0             80W /  400W |   45949MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   2  NVIDIA A100-SXM4-80GB          Off |   00000000:49:00.0 Off |                    0 |
# | N/A   50C    P0            297W /  400W |   74229MiB /  81920MiB |    100%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   3  NVIDIA A100-SXM4-80GB          Off |   00000000:4F:00.0 Off |                    0 |
# | N/A   39C    P0             84W /  400W |   71383MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   4  NVIDIA A100-SXM4-80GB          Off |   00000000:91:00.0 Off |                    0 |
# | N/A   56C    P0            315W /  400W |   41371MiB /  81920MiB |    100%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   5  NVIDIA A100-SXM4-80GB          Off |   00000000:97:00.0 Off |                    0 |
# | N/A   27C    P0             61W /  400W |       3MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   6  NVIDIA A100-SXM4-80GB          Off |   00000000:CD:00.0 Off |                    0 |
# | N/A   65C    P0            330W /  400W |   48647MiB /  81920MiB |    100%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   7  NVIDIA A100-SXM4-80GB          Off |   00000000:D2:00.0 Off |                    0 |
# | N/A   51C    P0            206W /  400W |   19927MiB /  81920MiB |     75%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A   1186431      C   python                                      69290MiB |
# |    1   N/A  N/A   1186431      C   python                                      45940MiB |
# |    2   N/A  N/A   1185962      C   python                                      74220MiB |
# |    3   N/A  N/A   1185962      C   python                                      71374MiB |
# |    4   N/A  N/A    936236      C   python                                      41362MiB |
# |    6   N/A  N/A   1225910      C   python                                      48638MiB |
# |    7   N/A  N/A   1240309      C   ...0110/anaconda3/envs/gpt2/bin/python      19918MiB |
# +-----------------------------------------------------------------------------------------+

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "5"

# %% [markdown]
# ## Setup the environment

# %%
# !pip install -q -U torch transformers bitsandbytes datasets huggingface_hub accelerate tqdm faiss-gpu matplotlib seaborn

# %%
from huggingface_hub import notebook_login
import os
import sys

# %%
os.environ["HF_TOKEN"] = "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"
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
def is_running_in_colab():
    return 'COLAB_GPU' in os.environ

if is_running_in_colab():
    # Load the Drive helper and mount
    print("Mounting google drive...")
    from google.colab import drive
    drive.mount('/content/drive')
else:
    print("Not running in Google Colab!")
# Out:
# Not running in Google Colab!

# %%
# !pwd
# Out:
# /home/nlp/achimoa/projects/hebrew_text_encoder/notebooks

# %%
project_dir = os.getcwd() if not os.getcwd().split("/")[-1] == 'notebooks' else '/'.join(os.getcwd().split("/")[0:-1])
src_dir = os.path.join(project_dir, 'src')

os.chdir(project_dir)
print(f"Current working directory set to: {os.getcwd()}")


if src_dir not in sys.path:
    sys.path.insert(0, src_dir)  # Add it to the front of PYTHONPATH
    print(f"PYTHONPATH updated with: {src_dir}")
else:
    print(f"PYTHONPATH already contains: {src_dir}")
# Out:
# Current working directory set to: /home/nlp/achimoa/projects/hebrew_text_encoder
# PYTHONPATH updated with: /home/nlp/achimoa/projects/hebrew_text_encoder/src

# %%
# %reload_ext autoreload
# %autoreload 2
import logging
from transformers import AutoModel, AutoTokenizer
import torch
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import re
from data import *
from evaluate import *
from utils import *

# %% [markdown]
# ## Evaluate the model

# %%
# Logger
log_file = f"./logs/hte_evaluation.log"
logger = setup_logger(log_file)
logger.info("*"*50)

# device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
logger.info(f"Using device: {device}")
# Out:
# 2024-10-13 12:09:35,726 - default - INFO - **************************************************
# 2024-10-13 12:09:35,985 - default - INFO - Using device: cuda

# %%
model_names = ['onlplab/alephbert-base', 'dicta-il/dictabert', 'intfloat/multilingual-e5-large']
tasks = ['TASK_QUERY_DOC', 'TASK_TITLE_DOC', 'TASK_QUESTION_DOC']
dataset_name='synthesized_query_document'

task_checkpoint_mapping = {
    'TASK_QUERY_DOC': 'synthesized_query_document',
    'TASK_TITLE_DOC': 'wiki40b',
    'TASK_QUESTION_DOC': 'heq',
}

eval_datasets = []
eval_dataset_tasks = build_eval_dataset(dataset_name=dataset_name)
for task, dataset in eval_dataset_tasks.items():
    eval_datasets.append((f"{dataset_name} ({task})", dataset_name, task, dataset))

eval_results = []
for model_name in model_names:
    for task in tasks:
        for dataset_name, dataset_name_orig, dataset_task, eval_dataset in eval_datasets:
            # Define model
            tokenizer = AutoTokenizer.from_pretrained(model_name)
            model = AutoModel.from_pretrained(model_name)
            model = model.to(device)

            # Add special tokens to the tokenizer
            new_tokens = [QUERY_TOKEN, DOCUMENT_TOKEN, *TASK_TOKENS.values()]
            additional_special_tokens = [token for token in new_tokens if token not in tokenizer.get_vocab()]
            logger.debug(f"Adding special tokens: {additional_special_tokens}")
            special_tokens = {
                "additional_special_tokens": additional_special_tokens
            }
            tokenizer.add_special_tokens(special_tokens)
            model.resize_token_embeddings(len(tokenizer))

            model_name_slug = model_name.replace('/', '_').replace('-', '_')
            if task != 'TASK_GENERAL_DOC':
                checkpoint_dir = f"checkpoints/{model_name_slug}/checkpoints_{task_checkpoint_mapping[task]}"
                epoch = load_checkpoint(model, optimizer=None, checkpoint_dir=checkpoint_dir, device=device)
                print(f"Fine-tuned model loaded from checkpoint: {checkpoint_dir} on epoch: {epoch}")
            else:
                print(f"Using base model: {model_name}")

            # Get the queries and their related documents
            queries = eval_dataset['anchor_text'][:10000]
            queries = [f"{TASK_TOKENS.get(task, '')} {query}".strip() for query in queries]
            documents = eval_dataset['positive_text'][:10000]
            logger.info(f"Queries: {len(queries)}, Documents: {len(documents)}")
                    
            # Encode the queries and positive documents into embeddings
            model_id = f'{model_name_slug}_{task}'
            dataset_name_slug = re.sub(r'[\s/\-]', '_', dataset_name)
            logger.info(f"Encoding queries")
            query_embeddings = get_embeddings(
                queries,
                tokenizer,
                model,
                device,
                batch_size=1024,
                embedding_file_path=f'embeddings/{model_name_slug}/{dataset_name_slug}/queries.pkl'
            )
            logger.info(f"Encoding documents")
            doc_embeddings = get_embeddings(
                documents,
                tokenizer,
                model,
                device,
                batch_size=1024,
                embedding_file_path=f'embeddings/{model_name_slug}/{task}/documents.pkl'
            )

            # Create the index
            logger.info(f"Creating index")
            index = create_index(doc_embeddings)

            # Evaluate the model with k
            k_values = [1]
            for k in k_values:
                result = evaluate(query_embeddings, documents, index, k=k)
                eval_results.append(dict(
                        model_name=model_name,
                        task=task,
                        dataset_name=dataset_name,
                        k = k,
                        results = result
                    ))
                print(eval_results[-1])
# Out:
# 2024-10-13 12:37:28,391 - default - INFO - Building Synthesized Query Document evaluation dataset
# 2024-10-13 12:37:28,392 - default - INFO - Transforming synthesized dataset
# 2024-10-13 12:37:28,393 - default - INFO - Loading synthesize query document dataset from {data_folder_path}
# Loading data files:   0%|          | 0/13 [00:00<?, ?it/s]2024-10-13 12:37:28,395 - default - DEBUG - Loading data from synthetic_data_20240906_0018.pkl
# 2024-10-13 12:37:28,472 - default - DEBUG - Loading data from synthetic_data_20240920_0557.pkl
# 2024-10-13 12:37:28,473 - default - DEBUG - Loading data from synthetic_data_20240924_1958.pkl
# Loading data files:  23%|██▎       | 3/13 [00:00<00:00, 23.32it/s]2024-10-13 12:37:28,525 - default - DEBUG - Loading data from synthetic_data_20240924_1959.pkl
# 2024-10-13 12:37:28,623 - default - DEBUG - Loading data from synthetic_data_20240924_2023.pkl
# 2024-10-13 12:37:28,718 - default - DEBUG - Loading data from synthetic_data_20240930_1838.pkl
# Loading data files:  46%|████▌     | 6/13 [00:00<00:00, 14.08it/s]2024-10-13 12:37:28,797 - default - DEBUG - Loading data from synthetic_data_20240930_1845.pkl
# 2024-10-13 12:37:28,878 - default - DEBUG - Loading data from synthetic_data_20240930_1846.pkl
# Loading data files:  62%|██████▏   | 8/13 [00:00<00:00, 12.61it/s]2024-10-13 12:37:28,985 - default - DEBUG - Loading data from synthetic_data_20240930_1847.pkl
# 2024-10-13 12:37:29,051 - default - DEBUG - Loading data from synthetic_data_20241001_1259.pkl
# Loading data files:  77%|███████▋  | 10/13 [00:00<00:00, 13.47it/s]2024-10-13 12:37:29,114 - default - DEBUG - Loading data from synthetic_data_20241001_1302.pkl
# 2024-10-13 12:37:29,175 - default - DEBUG - Loading data from synthetic_data_20241001_1303.pkl
# Loading data files:  92%|█████████▏| 12/13 [00:00<00:00, 14.29it/s]2024-10-13 12:37:29,236 - default - DEBUG - Loading data from synthetic_data_20241001_1418.pkl
# Loading data files: 100%|██████████| 13/13 [00:00<00:00, 14.42it/s]
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:37:31,784 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:37:31,792 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# /home/nlp/achimoa/projects/hebrew_text_encoder/src/utils.py:54: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)
# 2024-10-13 12:37:32,251 - default - INFO - Queries: 9200, Documents: 9200
# 2024-10-13 12:37:32,253 - default - INFO - Encoding queries
# 2024-10-13 12:37:32,254 - default - INFO - Loading embeddings from embeddings/onlplab_alephbert_base/synthesized_query_document_(TASK_QUERY_DOC)/queries.pkl
# 2024-10-13 12:37:32,261 - default - INFO - Encoding documents
# 2024-10-13 12:37:32,263 - default - INFO - Loading embeddings from embeddings/onlplab_alephbert_base/TASK_QUERY_DOC/documents.pkl
# Fine-tuned model loaded from checkpoint: checkpoints/onlplab_alephbert_base/checkpoints_query_passge on epoch: 9
# 2024-10-13 12:37:32,407 - default - INFO - Creating index
# 2024-10-13 12:37:32,407 - default - INFO - Index 9200 documents
# 2024-10-13 12:37:32,411 - default - INFO - Total documents indexed: 9200
# 2024-10-13 12:37:33,562 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:37:33,641 - default - INFO - Average Precision@1: 0.5728260869565217
# 2024-10-13 12:37:33,641 - default - INFO - Average MRR: 0.5728260869565217
# 2024-10-13 12:37:33,642 - default - INFO - Average NDCG@1: 0.5728260869565217
# {'model_name': 'onlplab/alephbert-base', 'task': 'TASK_QUERY_DOC', 'dataset_name': 'synthesized_query_document (TASK_QUERY_DOC)', 'k': 1, 'results': {'precision': 0.5728260869565217, 'mrr': 0.5728260869565217, 'ndcg': 0.5728260869565217}}
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:37:35,591 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:37:35,599 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# 2024-10-13 12:37:36,030 - default - INFO - Queries: 9200, Documents: 9200
# 2024-10-13 12:37:36,032 - default - INFO - Encoding queries
# 2024-10-13 12:37:36,032 - default - INFO - Loading embeddings from embeddings/onlplab_alephbert_base/synthesized_query_document_(TASK_QUERY_DOC)/queries.pkl
# 2024-10-13 12:37:36,038 - default - INFO - Encoding documents
# 2024-10-13 12:37:36,040 - default - INFO - Loading embeddings from embeddings/onlplab_alephbert_base/TASK_TITLE_DOC/documents.pkl
# 2024-10-13 12:37:36,137 - default - INFO - Creating index
# 2024-10-13 12:37:36,137 - default - INFO - Index 9200 documents
# Fine-tuned model loaded from checkpoint: checkpoints/onlplab_alephbert_base/checkpoints_title_passge on epoch: 9
# 2024-10-13 12:37:36,143 - default - INFO - Total documents indexed: 9200
# 2024-10-13 12:37:37,284 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:37:37,364 - default - INFO - Average Precision@1: 0.05358695652173913
# 2024-10-13 12:37:37,364 - default - INFO - Average MRR: 0.05358695652173913
# 2024-10-13 12:37:37,365 - default - INFO - Average NDCG@1: 0.05358695652173913
# {'model_name': 'onlplab/alephbert-base', 'task': 'TASK_TITLE_DOC', 'dataset_name': 'synthesized_query_document (TASK_QUERY_DOC)', 'k': 1, 'results': {'precision': 0.05358695652173913, 'mrr': 0.05358695652173913, 'ndcg': 0.05358695652173913}}
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:37:38,197 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:37:38,205 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# 2024-10-13 12:37:38,771 - default - INFO - Queries: 9200, Documents: 9200
# 2024-10-13 12:37:38,773 - default - INFO - Encoding queries
# 2024-10-13 12:37:38,773 - default - INFO - Loading embeddings from embeddings/onlplab_alephbert_base/synthesized_query_document_(TASK_QUERY_DOC)/queries.pkl
# 2024-10-13 12:37:38,781 - default - INFO - Encoding documents
# 2024-10-13 12:37:38,782 - default - INFO - Loading embeddings from embeddings/onlplab_alephbert_base/TASK_QUESTION_DOC/documents.pkl
# 2024-10-13 12:37:38,868 - default - INFO - Creating index
# 2024-10-13 12:37:38,868 - default - INFO - Index 9200 documents
# 2024-10-13 12:37:38,874 - default - INFO - Total documents indexed: 9200
# Fine-tuned model loaded from checkpoint: checkpoints/onlplab_alephbert_base/checkpoints_question_passge on epoch: 9
# 2024-10-13 12:37:40,032 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:37:40,111 - default - INFO - Average Precision@1: 0.11978260869565217
# 2024-10-13 12:37:40,112 - default - INFO - Average MRR: 0.11978260869565217
# 2024-10-13 12:37:40,113 - default - INFO - Average NDCG@1: 0.11978260869565217
# {'model_name': 'onlplab/alephbert-base', 'task': 'TASK_QUESTION_DOC', 'dataset_name': 'synthesized_query_document (TASK_QUERY_DOC)', 'k': 1, 'results': {'precision': 0.11978260869565217, 'mrr': 0.11978260869565217, 'ndcg': 0.11978260869565217}}
# Some weights of BertModel were not initialized from the model checkpoint at dicta-il/dictabert and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:37:41,655 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:37:41,674 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# 2024-10-13 12:37:42,338 - default - INFO - Queries: 9200, Documents: 9200
# 2024-10-13 12:37:42,339 - default - INFO - Encoding queries
# 2024-10-13 12:37:42,341 - default - INFO - Loading embeddings from embeddings/dicta_il_dictabert/synthesized_query_document_(TASK_QUERY_DOC)/queries.pkl
# 2024-10-13 12:37:42,348 - default - INFO - Encoding documents
# 2024-10-13 12:37:42,349 - default - INFO - Loading embeddings from embeddings/dicta_il_dictabert/TASK_QUERY_DOC/documents.pkl
# 2024-10-13 12:37:42,424 - default - INFO - Creating index
# 2024-10-13 12:37:42,425 - default - INFO - Index 9200 documents
# 2024-10-13 12:37:42,433 - default - INFO - Total documents indexed: 9200
# Fine-tuned model loaded from checkpoint: checkpoints/dicta_il_dictabert/checkpoints_query_passge on epoch: 9
# 2024-10-13 12:37:43,603 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:37:43,680 - default - INFO - Average Precision@1: 0.6097826086956522
# 2024-10-13 12:37:43,681 - default - INFO - Average MRR: 0.6097826086956522
# 2024-10-13 12:37:43,681 - default - INFO - Average NDCG@1: 0.6097826086956522
# {'model_name': 'dicta-il/dictabert', 'task': 'TASK_QUERY_DOC', 'dataset_name': 'synthesized_query_document (TASK_QUERY_DOC)', 'k': 1, 'results': {'precision': 0.6097826086956522, 'mrr': 0.6097826086956522, 'ndcg': 0.6097826086956522}}
# Some weights of BertModel were not initialized from the model checkpoint at dicta-il/dictabert and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:37:45,208 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:37:45,225 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# Fine-tuned model loaded from checkpoint: checkpoints/dicta_il_dictabert/checkpoints_title_passge on epoch: 9
# 2024-10-13 12:37:46,175 - default - INFO - Queries: 9200, Documents: 9200
# 2024-10-13 12:37:46,176 - default - INFO - Encoding queries
# 2024-10-13 12:37:46,177 - default - INFO - Loading embeddings from embeddings/dicta_il_dictabert/synthesized_query_document_(TASK_QUERY_DOC)/queries.pkl
# 2024-10-13 12:37:46,183 - default - INFO - Encoding documents
# 2024-10-13 12:37:46,185 - default - INFO - Loading embeddings from embeddings/dicta_il_dictabert/TASK_TITLE_DOC/documents.pkl
# 2024-10-13 12:37:46,271 - default - INFO - Creating index
# 2024-10-13 12:37:46,271 - default - INFO - Index 9200 documents
# 2024-10-13 12:37:46,276 - default - INFO - Total documents indexed: 9200
# 2024-10-13 12:37:47,433 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:37:47,510 - default - INFO - Average Precision@1: 0.11054347826086956
# 2024-10-13 12:37:47,511 - default - INFO - Average MRR: 0.11054347826086956
# 2024-10-13 12:37:47,512 - default - INFO - Average NDCG@1: 0.11054347826086956
# {'model_name': 'dicta-il/dictabert', 'task': 'TASK_TITLE_DOC', 'dataset_name': 'synthesized_query_document (TASK_QUERY_DOC)', 'k': 1, 'results': {'precision': 0.11054347826086956, 'mrr': 0.11054347826086956, 'ndcg': 0.11054347826086956}}
# Some weights of BertModel were not initialized from the model checkpoint at dicta-il/dictabert and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:37:48,502 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:37:48,530 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# 2024-10-13 12:37:49,099 - default - INFO - Queries: 9200, Documents: 9200
# 2024-10-13 12:37:49,100 - default - INFO - Encoding queries
# 2024-10-13 12:37:49,101 - default - INFO - Loading embeddings from embeddings/dicta_il_dictabert/synthesized_query_document_(TASK_QUERY_DOC)/queries.pkl
# 2024-10-13 12:37:49,106 - default - INFO - Encoding documents
# 2024-10-13 12:37:49,108 - default - INFO - Loading embeddings from embeddings/dicta_il_dictabert/TASK_QUESTION_DOC/documents.pkl
# 2024-10-13 12:37:49,166 - default - INFO - Creating index
# 2024-10-13 12:37:49,166 - default - INFO - Index 9200 documents
# 2024-10-13 12:37:49,171 - default - INFO - Total documents indexed: 9200
# Fine-tuned model loaded from checkpoint: checkpoints/dicta_il_dictabert/checkpoints_question_passge on epoch: 9
# 2024-10-13 12:37:50,336 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:37:50,413 - default - INFO - Average Precision@1: 0.20717391304347826
# 2024-10-13 12:37:50,413 - default - INFO - Average MRR: 0.20717391304347826
# 2024-10-13 12:37:50,414 - default - INFO - Average NDCG@1: 0.20717391304347826
# {'model_name': 'dicta-il/dictabert', 'task': 'TASK_QUESTION_DOC', 'dataset_name': 'synthesized_query_document (TASK_QUERY_DOC)', 'k': 1, 'results': {'precision': 0.20717391304347826, 'mrr': 0.20717391304347826, 'ndcg': 0.20717391304347826}}
# 2024-10-13 12:37:53,208 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:37:53,252 - default - INFO - Loading checkpoint checkpoint_epoch_5.pth
# 2024-10-13 12:37:54,638 - default - INFO - Queries: 9200, Documents: 9200
# 2024-10-13 12:37:54,639 - default - INFO - Encoding queries
# 2024-10-13 12:37:54,640 - default - INFO - Loading embeddings from embeddings/intfloat_multilingual_e5_large/synthesized_query_document_(TASK_QUERY_DOC)/queries.pkl
# 2024-10-13 12:37:54,654 - default - INFO - Encoding documents
# 2024-10-13 12:37:54,655 - default - INFO - Loading embeddings from embeddings/intfloat_multilingual_e5_large/TASK_QUERY_DOC/documents.pkl
# Fine-tuned model loaded from checkpoint: checkpoints/intfloat_multilingual_e5_large/checkpoints_query_passge on epoch: 5
# 2024-10-13 12:37:54,768 - default - INFO - Creating index
# 2024-10-13 12:37:54,768 - default - INFO - Index 9200 documents
# 2024-10-13 12:37:54,791 - default - INFO - Total documents indexed: 9200
# 2024-10-13 12:37:55,960 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:37:56,041 - default - INFO - Average Precision@1: 0.4980434782608696
# 2024-10-13 12:37:56,041 - default - INFO - Average MRR: 0.4980434782608696
# 2024-10-13 12:37:56,042 - default - INFO - Average NDCG@1: 0.4980434782608696
# {'model_name': 'intfloat/multilingual-e5-large', 'task': 'TASK_QUERY_DOC', 'dataset_name': 'synthesized_query_document (TASK_QUERY_DOC)', 'k': 1, 'results': {'precision': 0.4980434782608696, 'mrr': 0.4980434782608696, 'ndcg': 0.4980434782608696}}
# 2024-10-13 12:37:59,069 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:37:59,110 - default - INFO - Loading checkpoint checkpoint_epoch_8.pth
# Fine-tuned model loaded from checkpoint: checkpoints/intfloat_multilingual_e5_large/checkpoints_title_passge on epoch: 8
# 2024-10-13 12:38:00,607 - default - INFO - Queries: 9200, Documents: 9200
# 2024-10-13 12:38:00,608 - default - INFO - Encoding queries
# 2024-10-13 12:38:00,610 - default - INFO - Loading embeddings from embeddings/intfloat_multilingual_e5_large/synthesized_query_document_(TASK_QUERY_DOC)/queries.pkl
# 2024-10-13 12:38:00,624 - default - INFO - Encoding documents
# 2024-10-13 12:38:00,626 - default - INFO - Loading embeddings from embeddings/intfloat_multilingual_e5_large/TASK_TITLE_DOC/documents.pkl
# 2024-10-13 12:38:00,757 - default - INFO - Creating index
# 2024-10-13 12:38:00,757 - default - INFO - Index 9200 documents
# 2024-10-13 12:38:00,770 - default - INFO - Total documents indexed: 9200
# 2024-10-13 12:38:01,953 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:38:02,029 - default - INFO - Average Precision@1: 0.11706521739130435
# 2024-10-13 12:38:02,029 - default - INFO - Average MRR: 0.11706521739130435
# 2024-10-13 12:38:02,031 - default - INFO - Average NDCG@1: 0.11706521739130435
# {'model_name': 'intfloat/multilingual-e5-large', 'task': 'TASK_TITLE_DOC', 'dataset_name': 'synthesized_query_document (TASK_QUERY_DOC)', 'k': 1, 'results': {'precision': 0.11706521739130435, 'mrr': 0.11706521739130435, 'ndcg': 0.11706521739130435}}
# 2024-10-13 12:38:04,327 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:38:04,368 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# 2024-10-13 12:38:05,831 - default - INFO - Queries: 9200, Documents: 9200
# 2024-10-13 12:38:05,832 - default - INFO - Encoding queries
# 2024-10-13 12:38:05,833 - default - INFO - Loading embeddings from embeddings/intfloat_multilingual_e5_large/synthesized_query_document_(TASK_QUERY_DOC)/queries.pkl
# 2024-10-13 12:38:05,839 - default - INFO - Encoding documents
# 2024-10-13 12:38:05,841 - default - INFO - Loading embeddings from embeddings/intfloat_multilingual_e5_large/TASK_QUESTION_DOC/documents.pkl
# Fine-tuned model loaded from checkpoint: checkpoints/intfloat_multilingual_e5_large/checkpoints_question_passge on epoch: 9
# 2024-10-13 12:38:06,035 - default - INFO - Creating index
# 2024-10-13 12:38:06,035 - default - INFO - Index 9200 documents
# 2024-10-13 12:38:06,042 - default - INFO - Total documents indexed: 9200
# 2024-10-13 12:38:07,201 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:38:07,277 - default - INFO - Average Precision@1: 0.18195652173913043
# 2024-10-13 12:38:07,278 - default - INFO - Average MRR: 0.18195652173913043
# 2024-10-13 12:38:07,279 - default - INFO - Average NDCG@1: 0.18195652173913043
# {'model_name': 'intfloat/multilingual-e5-large', 'task': 'TASK_QUESTION_DOC', 'dataset_name': 'synthesized_query_document (TASK_QUERY_DOC)', 'k': 1, 'results': {'precision': 0.18195652173913043, 'mrr': 0.18195652173913043, 'ndcg': 0.18195652173913043}}

# %%
result
# Out:
# {'precision': 0.5967, 'mrr': 0.5967, 'ndcg': 0.5967}

# %%
model_names = ['onlplab/alephbert-base', 'dicta-il/dictabert', 'intfloat/multilingual-e5-large']

dataset_names = [dataset_name.value for dataset_name in DatasetName]
eval_datasets = []
for dataset_name in dataset_names:
    eval_dataset_tasks = build_eval_dataset(dataset_name=dataset_name)
    for task, dataset in eval_dataset_tasks.items():
        eval_datasets.append((f"{dataset_name} ({task})", dataset_name, task, dataset))

tasks = list(TASK_TOKENS.keys()) + ['TASK_GENERAL_DOC']
task_checkpoint_mapping = {
    'TASK_QUERY_DOC': 'synthesized_query_document',
    'TASK_TITLE_DOC': 'wiki40b',
    'TASK_QUESTION_DOC': 'heq',
}

eval_results = []
for model_name in model_names:
    for task in tasks: # sim_title_doc, sim_query_doc, sim_question_doc, sim_general_doc
        for dataset_name, dataset_name_orig, dataset_task, eval_dataset in eval_datasets: # wiki40b, synthesized_query_document, heq
            logger.info(f"Model: {model_name}")
            logger.info(f"Task: {task}")
            logger.info(f"Eval dataset Name: {dataset_name}")

            # Define model
            tokenizer = AutoTokenizer.from_pretrained(model_name)
            model = AutoModel.from_pretrained(model_name)
            model = model.to(device)

            # Add special tokens to the tokenizer
            new_tokens = [QUERY_TOKEN, DOCUMENT_TOKEN, *TASK_TOKENS.values()]
            additional_special_tokens = [token for token in new_tokens if token not in tokenizer.get_vocab()]
            logger.debug(f"Adding special tokens: {additional_special_tokens}")
            special_tokens = {
                "additional_special_tokens": additional_special_tokens
            }
            tokenizer.add_special_tokens(special_tokens)
            model.resize_token_embeddings(len(tokenizer))

            model_name_slug = model_name.replace('/', '_').replace('-', '_')
            if task != 'TASK_GENERAL_DOC':
                checkpoint_dir = f"checkpoints/{model_name_slug}/checkpoints_{task_checkpoint_mapping[task]}"
                epoch = load_checkpoint(model, optimizer=None, checkpoint_dir=checkpoint_dir, device=device)
                logger.info(f"Fine-tuned model loaded from checkpoint: {checkpoint_dir} on epoch: {epoch}")
            else:
                logger.info(f"Using base model: {model_name}")

            # Get the queries and their related documents
            queries = eval_dataset['anchor_text']
            queries = [f"{TASK_TOKENS.get(task, '')} {query}".strip() for query in queries]
            documents = eval_dataset['positive_text']
            logger.info(f"Queries: {len(queries)}, Documents: {len(documents)}")
                   
            # Encode the queries and positive documents into embeddings
            dataset_name_slug = re.sub(r'[\s/\-]', '_', dataset_name)
            logger.info(f"Encoding queries")
            query_embeddings = get_embeddings(
                queries,
                tokenizer,
                model,
                device,
                batch_size=1024,
                embedding_file_path=f'embeddings/{model_name_slug}/{task}/{dataset_name_slug}/queries.pkl'
            )
            logger.info(f"Encoding documents")
            doc_embeddings = get_embeddings(
                documents,
                tokenizer,
                model,
                device,
                batch_size=1024,
                embedding_file_path=f'embeddings/{model_name_slug}/{task}/{dataset_name_slug}/documents.pkl'
            )

            # Create the index
            logger.info(f"Creating index")
            index = create_index(doc_embeddings)

            # Evaluate the model with k
            k_values = [1]
            for k in k_values:
                result = evaluate(query_embeddings, documents, index, k=k)
                eval_results.append(dict(
                    model_name=model_name,
                    task=task,
                    dataset_name=dataset_name,
                    k = k,
                    results = result
                ))
            
                logger.info(f"Results for model: {model_name}, task: {task}, dataset_name: {dataset_name},  k={k}: \n{result}")
# Out:
# 2024-10-13 12:46:33,659 - default - INFO - Building Synthesized Query Document evaluation dataset
# 2024-10-13 12:46:33,661 - default - INFO - Building Wiki40B dataset
# 2024-10-13 12:46:33,661 - default - INFO - Loading Wiki40B dataset
# 2024-10-13 12:46:42,072 - default - INFO - Transforming test split
# 2024-10-13 12:46:42,090 - default - INFO - Done transforming Wiki40B dataset
# 2024-10-13 12:46:42,100 - default - INFO - Building Synthesized Query Document evaluation dataset
# 2024-10-13 12:46:42,100 - default - INFO - Transforming synthesized dataset
# 2024-10-13 12:46:42,101 - default - INFO - Loading synthesize query document dataset from {data_folder_path}
# Loading data files:   0%|          | 0/13 [00:00<?, ?it/s]2024-10-13 12:46:42,103 - default - DEBUG - Loading data from synthetic_data_20240906_0018.pkl
# 2024-10-13 12:46:42,175 - default - DEBUG - Loading data from synthetic_data_20240920_0557.pkl
# 2024-10-13 12:46:42,177 - default - DEBUG - Loading data from synthetic_data_20240924_1958.pkl
# Loading data files:  23%|██▎       | 3/13 [00:00<00:00, 24.11it/s]2024-10-13 12:46:42,229 - default - DEBUG - Loading data from synthetic_data_20240924_1959.pkl
# 2024-10-13 12:46:42,326 - default - DEBUG - Loading data from synthetic_data_20240924_2023.pkl
# 2024-10-13 12:46:42,423 - default - DEBUG - Loading data from synthetic_data_20240930_1838.pkl
# Loading data files:  46%|████▌     | 6/13 [00:00<00:00, 13.96it/s]2024-10-13 12:46:42,506 - default - DEBUG - Loading data from synthetic_data_20240930_1845.pkl
# 2024-10-13 12:46:42,588 - default - DEBUG - Loading data from synthetic_data_20240930_1846.pkl
# Loading data files:  62%|██████▏   | 8/13 [00:00<00:00, 13.10it/s]2024-10-13 12:46:42,676 - default - DEBUG - Loading data from synthetic_data_20240930_1847.pkl
# 2024-10-13 12:46:42,738 - default - DEBUG - Loading data from synthetic_data_20241001_1259.pkl
# Loading data files:  77%|███████▋  | 10/13 [00:00<00:00, 14.04it/s]2024-10-13 12:46:42,798 - default - DEBUG - Loading data from synthetic_data_20241001_1302.pkl
# 2024-10-13 12:46:42,859 - default - DEBUG - Loading data from synthetic_data_20241001_1303.pkl
# Loading data files:  92%|█████████▏| 12/13 [00:00<00:00, 14.74it/s]2024-10-13 12:46:42,920 - default - DEBUG - Loading data from synthetic_data_20241001_1418.pkl
# Loading data files: 100%|██████████| 13/13 [00:00<00:00, 14.85it/s]
# 2024-10-13 12:46:44,326 - default - INFO - Building HeQ evaluation dataset
# 2024-10-13 12:46:44,327 - default - INFO - Loading json file from https://raw.githubusercontent.com/NNLP-IL/Hebrew-Question-Answering-Dataset/main/data/test.json
# 2024-10-13 12:46:44,881 - default - INFO - Model: onlplab/alephbert-base
# 2024-10-13 12:46:44,882 - default - INFO - Task: TASK_QUERY_DOC
# 2024-10-13 12:46:44,882 - default - INFO - Eval dataset Name: wiki40b (TASK_TITLE_DOC)
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:46:46,277 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:46:46,285 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# /home/nlp/achimoa/projects/hebrew_text_encoder/src/utils.py:54: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)
# 2024-10-13 12:46:46,629 - default - INFO - Fine-tuned model loaded from checkpoint: checkpoints/onlplab_alephbert_base/checkpoints_query_passge on epoch: 9
# 2024-10-13 12:46:46,666 - default - INFO - Queries: 9344, Documents: 9344
# 2024-10-13 12:46:46,667 - default - INFO - Encoding queries
# 2024-10-13 12:46:46,669 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:02<00:00,  3.68it/s]
# 2024-10-13 12:46:49,400 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_QUERY_DOC/wiki40b_(TASK_TITLE_DOC)/queries.pkl
# 2024-10-13 12:46:49,475 - default - INFO - Encoding documents
# 2024-10-13 12:46:49,476 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:43<00:00,  4.31s/it]
# 2024-10-13 12:47:32,576 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_QUERY_DOC/wiki40b_(TASK_TITLE_DOC)/documents.pkl
# 2024-10-13 12:47:32,649 - default - INFO - Creating index
# 2024-10-13 12:47:32,649 - default - INFO - Index 9344 documents
# 2024-10-13 12:47:32,653 - default - INFO - Total documents indexed: 9344
# 2024-10-13 12:47:33,925 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:47:34,010 - default - INFO - Average Precision@1: 0.1754066780821918
# 2024-10-13 12:47:34,011 - default - INFO - Average MRR: 0.1754066780821918
# 2024-10-13 12:47:34,012 - default - INFO - Average NDCG@1: 0.1754066780821918
# 2024-10-13 12:47:34,013 - default - INFO - Results for model: onlplab/alephbert-base, task: TASK_QUERY_DOC, dataset_name: wiki40b (TASK_TITLE_DOC),  k=1:
# {'precision': 0.1754066780821918, 'mrr': 0.1754066780821918, 'ndcg': 0.1754066780821918}
# 2024-10-13 12:47:34,013 - default - INFO - Model: onlplab/alephbert-base
# 2024-10-13 12:47:34,015 - default - INFO - Task: TASK_QUERY_DOC
# 2024-10-13 12:47:34,018 - default - INFO - Eval dataset Name: synthesized_query_document (TASK_QUERY_DOC)
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:47:35,432 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:47:35,439 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# 2024-10-13 12:47:35,785 - default - INFO - Fine-tuned model loaded from checkpoint: checkpoints/onlplab_alephbert_base/checkpoints_query_passge on epoch: 9
# 2024-10-13 12:47:35,888 - default - INFO - Queries: 9200, Documents: 9200
# 2024-10-13 12:47:35,889 - default - INFO - Encoding queries
# 2024-10-13 12:47:35,890 - default - INFO - Encode 9200 texts to their embeddings
# Encoding batches: 100%|██████████| 9/9 [00:09<00:00,  1.08s/it]
# 2024-10-13 12:47:45,613 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_QUERY_DOC/synthesized_query_document_(TASK_QUERY_DOC)/queries.pkl
# 2024-10-13 12:47:45,682 - default - INFO - Encoding documents
# 2024-10-13 12:47:45,683 - default - INFO - Encode 9200 texts to their embeddings
# Encoding batches: 100%|██████████| 9/9 [00:51<00:00,  5.75s/it]
# 2024-10-13 12:48:37,500 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_QUERY_DOC/synthesized_query_document_(TASK_QUERY_DOC)/documents.pkl
# 2024-10-13 12:48:37,586 - default - INFO - Creating index
# 2024-10-13 12:48:37,587 - default - INFO - Index 9200 documents
# 2024-10-13 12:48:37,591 - default - INFO - Total documents indexed: 9200
# 2024-10-13 12:48:38,757 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:48:38,832 - default - INFO - Average Precision@1: 0.5690217391304347
# 2024-10-13 12:48:38,832 - default - INFO - Average MRR: 0.5690217391304347
# 2024-10-13 12:48:38,833 - default - INFO - Average NDCG@1: 0.5690217391304347
# 2024-10-13 12:48:38,834 - default - INFO - Results for model: onlplab/alephbert-base, task: TASK_QUERY_DOC, dataset_name: synthesized_query_document (TASK_QUERY_DOC),  k=1:
# {'precision': 0.5690217391304347, 'mrr': 0.5690217391304347, 'ndcg': 0.5690217391304347}
# 2024-10-13 12:48:38,835 - default - INFO - Model: onlplab/alephbert-base
# 2024-10-13 12:48:38,836 - default - INFO - Task: TASK_QUERY_DOC
# 2024-10-13 12:48:38,837 - default - INFO - Eval dataset Name: heq (TASK_QUESTION_DOC)
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:48:39,714 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:48:39,722 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# 2024-10-13 12:48:40,070 - default - INFO - Fine-tuned model loaded from checkpoint: checkpoints/onlplab_alephbert_base/checkpoints_query_passge on epoch: 9
# 2024-10-13 12:48:40,082 - default - INFO - Queries: 238, Documents: 238
# 2024-10-13 12:48:40,082 - default - INFO - Encoding queries
# 2024-10-13 12:48:40,084 - default - INFO - Encode 238 texts to their embeddings
# Encoding batches: 100%|██████████| 1/1 [00:00<00:00, 11.66it/s]
# 2024-10-13 12:48:40,175 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_QUERY_DOC/heq_(TASK_QUESTION_DOC)/queries.pkl
# 2024-10-13 12:48:40,180 - default - INFO - Encoding documents
# 2024-10-13 12:48:40,181 - default - INFO - Encode 238 texts to their embeddings
# Encoding batches: 100%|██████████| 1/1 [00:00<00:00,  1.10it/s]
# 2024-10-13 12:48:41,104 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_QUERY_DOC/heq_(TASK_QUESTION_DOC)/documents.pkl
# 2024-10-13 12:48:41,109 - default - INFO - Creating index
# 2024-10-13 12:48:41,109 - default - INFO - Index 238 documents
# 2024-10-13 12:48:41,110 - default - INFO - Total documents indexed: 238
# 2024-10-13 12:48:41,144 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:48:41,147 - default - INFO - Average Precision@1: 0.42016806722689076
# 2024-10-13 12:48:41,147 - default - INFO - Average MRR: 0.42016806722689076
# 2024-10-13 12:48:41,148 - default - INFO - Average NDCG@1: 0.42016806722689076
# 2024-10-13 12:48:41,148 - default - INFO - Results for model: onlplab/alephbert-base, task: TASK_QUERY_DOC, dataset_name: heq (TASK_QUESTION_DOC),  k=1:
# {'precision': 0.42016806722689076, 'mrr': 0.42016806722689076, 'ndcg': 0.42016806722689076}
# 2024-10-13 12:48:41,149 - default - INFO - Model: onlplab/alephbert-base
# 2024-10-13 12:48:41,149 - default - INFO - Task: TASK_QUERY_DOC
# 2024-10-13 12:48:41,150 - default - INFO - Eval dataset Name: heq (TASK_TITLE_DOC)
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:48:41,967 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:48:41,976 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# 2024-10-13 12:48:42,319 - default - INFO - Fine-tuned model loaded from checkpoint: checkpoints/onlplab_alephbert_base/checkpoints_query_passge on epoch: 9
# 2024-10-13 12:48:42,322 - default - INFO - Queries: 238, Documents: 238
# 2024-10-13 12:48:42,323 - default - INFO - Encoding queries
# 2024-10-13 12:48:42,324 - default - INFO - Encode 238 texts to their embeddings
# Encoding batches: 100%|██████████| 1/1 [00:00<00:00, 10.90it/s]
# 2024-10-13 12:48:42,421 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_QUERY_DOC/heq_(TASK_TITLE_DOC)/queries.pkl
# 2024-10-13 12:48:42,426 - default - INFO - Encoding documents
# 2024-10-13 12:48:42,427 - default - INFO - Encode 238 texts to their embeddings
# Encoding batches: 100%|██████████| 1/1 [00:00<00:00,  1.14it/s]
# 2024-10-13 12:48:43,323 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_QUERY_DOC/heq_(TASK_TITLE_DOC)/documents.pkl
# 2024-10-13 12:48:43,329 - default - INFO - Creating index
# 2024-10-13 12:48:43,330 - default - INFO - Index 238 documents
# 2024-10-13 12:48:43,331 - default - INFO - Total documents indexed: 238
# 2024-10-13 12:48:43,365 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:48:43,374 - default - INFO - Average Precision@1: 0.3403361344537815
# 2024-10-13 12:48:43,374 - default - INFO - Average MRR: 0.3403361344537815
# 2024-10-13 12:48:43,375 - default - INFO - Average NDCG@1: 0.3403361344537815
# 2024-10-13 12:48:43,375 - default - INFO - Results for model: onlplab/alephbert-base, task: TASK_QUERY_DOC, dataset_name: heq (TASK_TITLE_DOC),  k=1:
# {'precision': 0.3403361344537815, 'mrr': 0.3403361344537815, 'ndcg': 0.3403361344537815}
# 2024-10-13 12:48:43,376 - default - INFO - Model: onlplab/alephbert-base
# 2024-10-13 12:48:43,376 - default - INFO - Task: TASK_TITLE_DOC
# 2024-10-13 12:48:43,377 - default - INFO - Eval dataset Name: wiki40b (TASK_TITLE_DOC)
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:48:44,721 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:48:44,729 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# 2024-10-13 12:48:45,070 - default - INFO - Fine-tuned model loaded from checkpoint: checkpoints/onlplab_alephbert_base/checkpoints_title_passge on epoch: 9
# 2024-10-13 12:48:45,105 - default - INFO - Queries: 9344, Documents: 9344
# 2024-10-13 12:48:45,105 - default - INFO - Encoding queries
# 2024-10-13 12:48:45,107 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:02<00:00,  3.73it/s]
# 2024-10-13 12:48:47,809 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_TITLE_DOC/wiki40b_(TASK_TITLE_DOC)/queries.pkl
# 2024-10-13 12:48:47,889 - default - INFO - Encoding documents
# 2024-10-13 12:48:47,890 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:42<00:00,  4.29s/it]
# 2024-10-13 12:49:30,783 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_TITLE_DOC/wiki40b_(TASK_TITLE_DOC)/documents.pkl
# 2024-10-13 12:49:30,852 - default - INFO - Creating index
# 2024-10-13 12:49:30,852 - default - INFO - Index 9344 documents
# 2024-10-13 12:49:30,856 - default - INFO - Total documents indexed: 9344
# 2024-10-13 12:49:32,129 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:49:32,209 - default - INFO - Average Precision@1: 0.6523972602739726
# 2024-10-13 12:49:32,209 - default - INFO - Average MRR: 0.6523972602739726
# 2024-10-13 12:49:32,211 - default - INFO - Average NDCG@1: 0.6523972602739726
# 2024-10-13 12:49:32,212 - default - INFO - Results for model: onlplab/alephbert-base, task: TASK_TITLE_DOC, dataset_name: wiki40b (TASK_TITLE_DOC),  k=1:
# {'precision': 0.6523972602739726, 'mrr': 0.6523972602739726, 'ndcg': 0.6523972602739726}
# 2024-10-13 12:49:32,213 - default - INFO - Model: onlplab/alephbert-base
# 2024-10-13 12:49:32,214 - default - INFO - Task: TASK_TITLE_DOC
# 2024-10-13 12:49:32,215 - default - INFO - Eval dataset Name: synthesized_query_document (TASK_QUERY_DOC)
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:49:33,609 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:49:33,617 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# 2024-10-13 12:49:33,966 - default - INFO - Fine-tuned model loaded from checkpoint: checkpoints/onlplab_alephbert_base/checkpoints_title_passge on epoch: 9
# 2024-10-13 12:49:34,075 - default - INFO - Queries: 9200, Documents: 9200
# 2024-10-13 12:49:34,076 - default - INFO - Encoding queries
# 2024-10-13 12:49:34,078 - default - INFO - Encode 9200 texts to their embeddings
# Encoding batches: 100%|██████████| 9/9 [00:09<00:00,  1.08s/it]
# 2024-10-13 12:49:43,806 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_TITLE_DOC/synthesized_query_document_(TASK_QUERY_DOC)/queries.pkl
# 2024-10-13 12:49:43,882 - default - INFO - Encoding documents
# 2024-10-13 12:49:43,883 - default - INFO - Encode 9200 texts to their embeddings
# Encoding batches: 100%|██████████| 9/9 [00:51<00:00,  5.77s/it]
# 2024-10-13 12:50:35,883 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_TITLE_DOC/synthesized_query_document_(TASK_QUERY_DOC)/documents.pkl
# 2024-10-13 12:50:36,006 - default - INFO - Creating index
# 2024-10-13 12:50:36,006 - default - INFO - Index 9200 documents
# 2024-10-13 12:50:36,011 - default - INFO - Total documents indexed: 9200
# 2024-10-13 12:50:37,160 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:50:37,238 - default - INFO - Average Precision@1: 0.1716304347826087
# 2024-10-13 12:50:37,239 - default - INFO - Average MRR: 0.1716304347826087
# 2024-10-13 12:50:37,239 - default - INFO - Average NDCG@1: 0.1716304347826087
# 2024-10-13 12:50:37,240 - default - INFO - Results for model: onlplab/alephbert-base, task: TASK_TITLE_DOC, dataset_name: synthesized_query_document (TASK_QUERY_DOC),  k=1:
# {'precision': 0.1716304347826087, 'mrr': 0.1716304347826087, 'ndcg': 0.1716304347826087}
# 2024-10-13 12:50:37,241 - default - INFO - Model: onlplab/alephbert-base
# 2024-10-13 12:50:37,241 - default - INFO - Task: TASK_TITLE_DOC
# 2024-10-13 12:50:37,242 - default - INFO - Eval dataset Name: heq (TASK_QUESTION_DOC)
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:50:38,662 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:50:38,671 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# 2024-10-13 12:50:39,017 - default - INFO - Fine-tuned model loaded from checkpoint: checkpoints/onlplab_alephbert_base/checkpoints_title_passge on epoch: 9
# 2024-10-13 12:50:39,027 - default - INFO - Queries: 238, Documents: 238
# 2024-10-13 12:50:39,028 - default - INFO - Encoding queries
# 2024-10-13 12:50:39,029 - default - INFO - Encode 238 texts to their embeddings
# Encoding batches: 100%|██████████| 1/1 [00:00<00:00, 11.50it/s]
# 2024-10-13 12:50:39,121 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_TITLE_DOC/heq_(TASK_QUESTION_DOC)/queries.pkl
# 2024-10-13 12:50:39,126 - default - INFO - Encoding documents
# 2024-10-13 12:50:39,127 - default - INFO - Encode 238 texts to their embeddings
# Encoding batches: 100%|██████████| 1/1 [00:00<00:00,  1.12it/s]
# 2024-10-13 12:50:40,031 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_TITLE_DOC/heq_(TASK_QUESTION_DOC)/documents.pkl
# 2024-10-13 12:50:40,036 - default - INFO - Creating index
# 2024-10-13 12:50:40,036 - default - INFO - Index 238 documents
# 2024-10-13 12:50:40,037 - default - INFO - Total documents indexed: 238
# 2024-10-13 12:50:40,071 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:50:40,073 - default - INFO - Average Precision@1: 0.4411764705882353
# 2024-10-13 12:50:40,074 - default - INFO - Average MRR: 0.4411764705882353
# 2024-10-13 12:50:40,077 - default - INFO - Average NDCG@1: 0.4411764705882353
# 2024-10-13 12:50:40,078 - default - INFO - Results for model: onlplab/alephbert-base, task: TASK_TITLE_DOC, dataset_name: heq (TASK_QUESTION_DOC),  k=1:
# {'precision': 0.4411764705882353, 'mrr': 0.4411764705882353, 'ndcg': 0.4411764705882353}
# 2024-10-13 12:50:40,078 - default - INFO - Model: onlplab/alephbert-base
# 2024-10-13 12:50:40,079 - default - INFO - Task: TASK_TITLE_DOC
# 2024-10-13 12:50:40,079 - default - INFO - Eval dataset Name: heq (TASK_TITLE_DOC)
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:50:40,952 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:50:40,961 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# 2024-10-13 12:50:41,296 - default - INFO - Fine-tuned model loaded from checkpoint: checkpoints/onlplab_alephbert_base/checkpoints_title_passge on epoch: 9
# 2024-10-13 12:50:41,299 - default - INFO - Queries: 238, Documents: 238
# 2024-10-13 12:50:41,299 - default - INFO - Encoding queries
# 2024-10-13 12:50:41,300 - default - INFO - Encode 238 texts to their embeddings
# Encoding batches: 100%|██████████| 1/1 [00:00<00:00, 11.45it/s]
# 2024-10-13 12:50:41,393 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_TITLE_DOC/heq_(TASK_TITLE_DOC)/queries.pkl
# 2024-10-13 12:50:41,397 - default - INFO - Encoding documents
# 2024-10-13 12:50:41,398 - default - INFO - Encode 238 texts to their embeddings
# Encoding batches: 100%|██████████| 1/1 [00:00<00:00,  1.14it/s]
# 2024-10-13 12:50:42,288 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_TITLE_DOC/heq_(TASK_TITLE_DOC)/documents.pkl
# 2024-10-13 12:50:42,293 - default - INFO - Creating index
# 2024-10-13 12:50:42,294 - default - INFO - Index 238 documents
# 2024-10-13 12:50:42,295 - default - INFO - Total documents indexed: 238
# 2024-10-13 12:50:42,328 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:50:42,331 - default - INFO - Average Precision@1: 0.38235294117647056
# 2024-10-13 12:50:42,332 - default - INFO - Average MRR: 0.38235294117647056
# 2024-10-13 12:50:42,332 - default - INFO - Average NDCG@1: 0.38235294117647056
# 2024-10-13 12:50:42,333 - default - INFO - Results for model: onlplab/alephbert-base, task: TASK_TITLE_DOC, dataset_name: heq (TASK_TITLE_DOC),  k=1:
# {'precision': 0.38235294117647056, 'mrr': 0.38235294117647056, 'ndcg': 0.38235294117647056}
# 2024-10-13 12:50:42,333 - default - INFO - Model: onlplab/alephbert-base
# 2024-10-13 12:50:42,333 - default - INFO - Task: TASK_QUESTION_DOC
# 2024-10-13 12:50:42,334 - default - INFO - Eval dataset Name: wiki40b (TASK_TITLE_DOC)
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:50:43,158 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:50:43,167 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# 2024-10-13 12:50:43,643 - default - INFO - Fine-tuned model loaded from checkpoint: checkpoints/onlplab_alephbert_base/checkpoints_question_passge on epoch: 9
# 2024-10-13 12:50:43,677 - default - INFO - Queries: 9344, Documents: 9344
# 2024-10-13 12:50:43,678 - default - INFO - Encoding queries
# 2024-10-13 12:50:43,679 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:02<00:00,  3.73it/s]
# 2024-10-13 12:50:46,377 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_QUESTION_DOC/wiki40b_(TASK_TITLE_DOC)/queries.pkl
# 2024-10-13 12:50:46,473 - default - INFO - Encoding documents
# 2024-10-13 12:50:46,474 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:42<00:00,  4.28s/it]
# 2024-10-13 12:51:29,314 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_QUESTION_DOC/wiki40b_(TASK_TITLE_DOC)/documents.pkl
# 2024-10-13 12:51:29,399 - default - INFO - Creating index
# 2024-10-13 12:51:29,400 - default - INFO - Index 9344 documents
# 2024-10-13 12:51:29,406 - default - INFO - Total documents indexed: 9344
# 2024-10-13 12:51:30,684 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:51:30,766 - default - INFO - Average Precision@1: 0.4002568493150685
# 2024-10-13 12:51:30,766 - default - INFO - Average MRR: 0.4002568493150685
# 2024-10-13 12:51:30,767 - default - INFO - Average NDCG@1: 0.4002568493150685
# 2024-10-13 12:51:30,768 - default - INFO - Results for model: onlplab/alephbert-base, task: TASK_QUESTION_DOC, dataset_name: wiki40b (TASK_TITLE_DOC),  k=1:
# {'precision': 0.4002568493150685, 'mrr': 0.4002568493150685, 'ndcg': 0.4002568493150685}
# 2024-10-13 12:51:30,768 - default - INFO - Model: onlplab/alephbert-base
# 2024-10-13 12:51:30,769 - default - INFO - Task: TASK_QUESTION_DOC
# 2024-10-13 12:51:30,769 - default - INFO - Eval dataset Name: synthesized_query_document (TASK_QUERY_DOC)
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:51:32,215 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:51:32,223 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# 2024-10-13 12:51:32,711 - default - INFO - Fine-tuned model loaded from checkpoint: checkpoints/onlplab_alephbert_base/checkpoints_question_passge on epoch: 9
# 2024-10-13 12:51:32,816 - default - INFO - Queries: 9200, Documents: 9200
# 2024-10-13 12:51:32,817 - default - INFO - Encoding queries
# 2024-10-13 12:51:32,819 - default - INFO - Encode 9200 texts to their embeddings
# Encoding batches: 100%|██████████| 9/9 [00:09<00:00,  1.10s/it]
# 2024-10-13 12:51:42,755 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_QUESTION_DOC/synthesized_query_document_(TASK_QUERY_DOC)/queries.pkl
# 2024-10-13 12:51:42,829 - default - INFO - Encoding documents
# 2024-10-13 12:51:42,830 - default - INFO - Encode 9200 texts to their embeddings
# Encoding batches: 100%|██████████| 9/9 [00:51<00:00,  5.74s/it]
# 2024-10-13 12:52:34,616 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_QUESTION_DOC/synthesized_query_document_(TASK_QUERY_DOC)/documents.pkl
# 2024-10-13 12:52:34,704 - default - INFO - Creating index
# 2024-10-13 12:52:34,705 - default - INFO - Index 9200 documents
# 2024-10-13 12:52:34,712 - default - INFO - Total documents indexed: 9200
# 2024-10-13 12:52:35,864 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:52:35,940 - default - INFO - Average Precision@1: 0.2608695652173913
# 2024-10-13 12:52:35,940 - default - INFO - Average MRR: 0.2608695652173913
# 2024-10-13 12:52:35,942 - default - INFO - Average NDCG@1: 0.2608695652173913
# 2024-10-13 12:52:35,948 - default - INFO - Results for model: onlplab/alephbert-base, task: TASK_QUESTION_DOC, dataset_name: synthesized_query_document (TASK_QUERY_DOC),  k=1:
# {'precision': 0.2608695652173913, 'mrr': 0.2608695652173913, 'ndcg': 0.2608695652173913}
# 2024-10-13 12:52:35,952 - default - INFO - Model: onlplab/alephbert-base
# 2024-10-13 12:52:35,954 - default - INFO - Task: TASK_QUESTION_DOC
# 2024-10-13 12:52:35,955 - default - INFO - Eval dataset Name: heq (TASK_QUESTION_DOC)
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:52:37,687 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:52:37,698 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# 2024-10-13 12:52:38,149 - default - INFO - Fine-tuned model loaded from checkpoint: checkpoints/onlplab_alephbert_base/checkpoints_question_passge on epoch: 9
# 2024-10-13 12:52:38,162 - default - INFO - Queries: 238, Documents: 238
# 2024-10-13 12:52:38,162 - default - INFO - Encoding queries
# 2024-10-13 12:52:38,164 - default - INFO - Encode 238 texts to their embeddings
# Encoding batches: 100%|██████████| 1/1 [00:00<00:00, 12.34it/s]
# 2024-10-13 12:52:38,250 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_QUESTION_DOC/heq_(TASK_QUESTION_DOC)/queries.pkl
# 2024-10-13 12:52:38,256 - default - INFO - Encoding documents
# 2024-10-13 12:52:38,257 - default - INFO - Encode 238 texts to their embeddings
# Encoding batches: 100%|██████████| 1/1 [00:00<00:00,  1.11it/s]
# 2024-10-13 12:52:39,170 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_QUESTION_DOC/heq_(TASK_QUESTION_DOC)/documents.pkl
# 2024-10-13 12:52:39,175 - default - INFO - Creating index
# 2024-10-13 12:52:39,175 - default - INFO - Index 238 documents
# 2024-10-13 12:52:39,176 - default - INFO - Total documents indexed: 238
# 2024-10-13 12:52:39,210 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:52:39,212 - default - INFO - Average Precision@1: 0.6470588235294118
# 2024-10-13 12:52:39,213 - default - INFO - Average MRR: 0.6470588235294118
# 2024-10-13 12:52:39,213 - default - INFO - Average NDCG@1: 0.6470588235294118
# 2024-10-13 12:52:39,214 - default - INFO - Results for model: onlplab/alephbert-base, task: TASK_QUESTION_DOC, dataset_name: heq (TASK_QUESTION_DOC),  k=1:
# {'precision': 0.6470588235294118, 'mrr': 0.6470588235294118, 'ndcg': 0.6470588235294118}
# 2024-10-13 12:52:39,214 - default - INFO - Model: onlplab/alephbert-base
# 2024-10-13 12:52:39,215 - default - INFO - Task: TASK_QUESTION_DOC
# 2024-10-13 12:52:39,215 - default - INFO - Eval dataset Name: heq (TASK_TITLE_DOC)
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:52:40,095 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:52:40,105 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# 2024-10-13 12:52:40,588 - default - INFO - Fine-tuned model loaded from checkpoint: checkpoints/onlplab_alephbert_base/checkpoints_question_passge on epoch: 9
# 2024-10-13 12:52:40,591 - default - INFO - Queries: 238, Documents: 238
# 2024-10-13 12:52:40,592 - default - INFO - Encoding queries
# 2024-10-13 12:52:40,593 - default - INFO - Encode 238 texts to their embeddings
# Encoding batches: 100%|██████████| 1/1 [00:00<00:00, 11.78it/s]
# 2024-10-13 12:52:40,683 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_QUESTION_DOC/heq_(TASK_TITLE_DOC)/queries.pkl
# 2024-10-13 12:52:40,688 - default - INFO - Encoding documents
# 2024-10-13 12:52:40,689 - default - INFO - Encode 238 texts to their embeddings
# Encoding batches: 100%|██████████| 1/1 [00:00<00:00,  1.15it/s]
# 2024-10-13 12:52:41,577 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_QUESTION_DOC/heq_(TASK_TITLE_DOC)/documents.pkl
# 2024-10-13 12:52:41,583 - default - INFO - Creating index
# 2024-10-13 12:52:41,583 - default - INFO - Index 238 documents
# 2024-10-13 12:52:41,584 - default - INFO - Total documents indexed: 238
# 2024-10-13 12:52:41,617 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:52:41,620 - default - INFO - Average Precision@1: 0.5126050420168067
# 2024-10-13 12:52:41,621 - default - INFO - Average MRR: 0.5126050420168067
# 2024-10-13 12:52:41,621 - default - INFO - Average NDCG@1: 0.5126050420168067
# 2024-10-13 12:52:41,622 - default - INFO - Results for model: onlplab/alephbert-base, task: TASK_QUESTION_DOC, dataset_name: heq (TASK_TITLE_DOC),  k=1:
# {'precision': 0.5126050420168067, 'mrr': 0.5126050420168067, 'ndcg': 0.5126050420168067}
# 2024-10-13 12:52:41,622 - default - INFO - Model: onlplab/alephbert-base
# 2024-10-13 12:52:41,623 - default - INFO - Task: TASK_GENERAL_DOC
# 2024-10-13 12:52:41,623 - default - INFO - Eval dataset Name: wiki40b (TASK_TITLE_DOC)
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:52:42,473 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:52:42,481 - default - INFO - Using base model: onlplab/alephbert-base
# 2024-10-13 12:52:42,515 - default - INFO - Queries: 9344, Documents: 9344
# 2024-10-13 12:52:42,516 - default - INFO - Encoding queries
# 2024-10-13 12:52:42,517 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:02<00:00,  3.84it/s]
# 2024-10-13 12:52:45,152 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_GENERAL_DOC/wiki40b_(TASK_TITLE_DOC)/queries.pkl
# 2024-10-13 12:52:45,260 - default - INFO - Encoding documents
# 2024-10-13 12:52:45,261 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:43<00:00,  4.31s/it]
# 2024-10-13 12:53:28,410 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_GENERAL_DOC/wiki40b_(TASK_TITLE_DOC)/documents.pkl
# 2024-10-13 12:53:28,492 - default - INFO - Creating index
# 2024-10-13 12:53:28,493 - default - INFO - Index 9344 documents
# 2024-10-13 12:53:28,497 - default - INFO - Total documents indexed: 9344
# 2024-10-13 12:53:29,769 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:53:29,846 - default - INFO - Average Precision@1: 0.11044520547945205
# 2024-10-13 12:53:29,846 - default - INFO - Average MRR: 0.11044520547945205
# 2024-10-13 12:53:29,848 - default - INFO - Average NDCG@1: 0.11044520547945205
# 2024-10-13 12:53:29,852 - default - INFO - Results for model: onlplab/alephbert-base, task: TASK_GENERAL_DOC, dataset_name: wiki40b (TASK_TITLE_DOC),  k=1:
# {'precision': 0.11044520547945205, 'mrr': 0.11044520547945205, 'ndcg': 0.11044520547945205}
# 2024-10-13 12:53:29,856 - default - INFO - Model: onlplab/alephbert-base
# 2024-10-13 12:53:29,860 - default - INFO - Task: TASK_GENERAL_DOC
# 2024-10-13 12:53:29,864 - default - INFO - Eval dataset Name: synthesized_query_document (TASK_QUERY_DOC)
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:53:31,065 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:53:31,074 - default - INFO - Using base model: onlplab/alephbert-base
# 2024-10-13 12:53:31,187 - default - INFO - Queries: 9200, Documents: 9200
# 2024-10-13 12:53:31,189 - default - INFO - Encoding queries
# 2024-10-13 12:53:31,190 - default - INFO - Encode 9200 texts to their embeddings
# Encoding batches: 100%|██████████| 9/9 [00:09<00:00,  1.07s/it]
# 2024-10-13 12:53:40,811 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_GENERAL_DOC/synthesized_query_document_(TASK_QUERY_DOC)/queries.pkl
# 2024-10-13 12:53:40,896 - default - INFO - Encoding documents
# 2024-10-13 12:53:40,897 - default - INFO - Encode 9200 texts to their embeddings
# Encoding batches: 100%|██████████| 9/9 [00:51<00:00,  5.76s/it]
# 2024-10-13 12:54:32,827 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_GENERAL_DOC/synthesized_query_document_(TASK_QUERY_DOC)/documents.pkl
# 2024-10-13 12:54:32,907 - default - INFO - Creating index
# 2024-10-13 12:54:32,908 - default - INFO - Index 9200 documents
# 2024-10-13 12:54:32,912 - default - INFO - Total documents indexed: 9200
# 2024-10-13 12:54:34,059 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:54:34,134 - default - INFO - Average Precision@1: 0.20097826086956522
# 2024-10-13 12:54:34,134 - default - INFO - Average MRR: 0.20097826086956522
# 2024-10-13 12:54:34,135 - default - INFO - Average NDCG@1: 0.20097826086956522
# 2024-10-13 12:54:34,136 - default - INFO - Results for model: onlplab/alephbert-base, task: TASK_GENERAL_DOC, dataset_name: synthesized_query_document (TASK_QUERY_DOC),  k=1:
# {'precision': 0.20097826086956522, 'mrr': 0.20097826086956522, 'ndcg': 0.20097826086956522}
# 2024-10-13 12:54:34,136 - default - INFO - Model: onlplab/alephbert-base
# 2024-10-13 12:54:34,136 - default - INFO - Task: TASK_GENERAL_DOC
# 2024-10-13 12:54:34,137 - default - INFO - Eval dataset Name: heq (TASK_QUESTION_DOC)
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:54:35,520 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:54:35,528 - default - INFO - Using base model: onlplab/alephbert-base
# 2024-10-13 12:54:35,539 - default - INFO - Queries: 238, Documents: 238
# 2024-10-13 12:54:35,540 - default - INFO - Encoding queries
# 2024-10-13 12:54:35,541 - default - INFO - Encode 238 texts to their embeddings
# Encoding batches: 100%|██████████| 1/1 [00:00<00:00, 11.95it/s]
# 2024-10-13 12:54:35,629 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_GENERAL_DOC/heq_(TASK_QUESTION_DOC)/queries.pkl
# 2024-10-13 12:54:35,633 - default - INFO - Encoding documents
# 2024-10-13 12:54:35,634 - default - INFO - Encode 238 texts to their embeddings
# Encoding batches: 100%|██████████| 1/1 [00:00<00:00,  1.14it/s]
# 2024-10-13 12:54:36,527 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_GENERAL_DOC/heq_(TASK_QUESTION_DOC)/documents.pkl
# 2024-10-13 12:54:36,532 - default - INFO - Creating index
# 2024-10-13 12:54:36,532 - default - INFO - Index 238 documents
# 2024-10-13 12:54:36,533 - default - INFO - Total documents indexed: 238
# 2024-10-13 12:54:36,574 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:54:36,576 - default - INFO - Average Precision@1: 0.5294117647058824
# 2024-10-13 12:54:36,577 - default - INFO - Average MRR: 0.5294117647058824
# 2024-10-13 12:54:36,577 - default - INFO - Average NDCG@1: 0.5294117647058824
# 2024-10-13 12:54:36,578 - default - INFO - Results for model: onlplab/alephbert-base, task: TASK_GENERAL_DOC, dataset_name: heq (TASK_QUESTION_DOC),  k=1:
# {'precision': 0.5294117647058824, 'mrr': 0.5294117647058824, 'ndcg': 0.5294117647058824}
# 2024-10-13 12:54:36,578 - default - INFO - Model: onlplab/alephbert-base
# 2024-10-13 12:54:36,579 - default - INFO - Task: TASK_GENERAL_DOC
# 2024-10-13 12:54:36,579 - default - INFO - Eval dataset Name: heq (TASK_TITLE_DOC)
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:54:37,466 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:54:37,475 - default - INFO - Using base model: onlplab/alephbert-base
# 2024-10-13 12:54:37,477 - default - INFO - Queries: 238, Documents: 238
# 2024-10-13 12:54:37,478 - default - INFO - Encoding queries
# 2024-10-13 12:54:37,479 - default - INFO - Encode 238 texts to their embeddings
# Encoding batches: 100%|██████████| 1/1 [00:00<00:00, 12.14it/s]
# 2024-10-13 12:54:37,566 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_GENERAL_DOC/heq_(TASK_TITLE_DOC)/queries.pkl
# 2024-10-13 12:54:37,571 - default - INFO - Encoding documents
# 2024-10-13 12:54:37,572 - default - INFO - Encode 238 texts to their embeddings
# Encoding batches: 100%|██████████| 1/1 [00:00<00:00,  1.14it/s]
# 2024-10-13 12:54:38,459 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/TASK_GENERAL_DOC/heq_(TASK_TITLE_DOC)/documents.pkl
# 2024-10-13 12:54:38,464 - default - INFO - Creating index
# 2024-10-13 12:54:38,465 - default - INFO - Index 238 documents
# 2024-10-13 12:54:38,465 - default - INFO - Total documents indexed: 238
# 2024-10-13 12:54:38,506 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:54:38,509 - default - INFO - Average Precision@1: 0.2773109243697479
# 2024-10-13 12:54:38,509 - default - INFO - Average MRR: 0.2773109243697479
# 2024-10-13 12:54:38,510 - default - INFO - Average NDCG@1: 0.2773109243697479
# 2024-10-13 12:54:38,510 - default - INFO - Results for model: onlplab/alephbert-base, task: TASK_GENERAL_DOC, dataset_name: heq (TASK_TITLE_DOC),  k=1:
# {'precision': 0.2773109243697479, 'mrr': 0.2773109243697479, 'ndcg': 0.2773109243697479}
# 2024-10-13 12:54:38,511 - default - INFO - Model: dicta-il/dictabert
# 2024-10-13 12:54:38,511 - default - INFO - Task: TASK_QUERY_DOC
# 2024-10-13 12:54:38,512 - default - INFO - Eval dataset Name: wiki40b (TASK_TITLE_DOC)
# Some weights of BertModel were not initialized from the model checkpoint at dicta-il/dictabert and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:54:39,565 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:54:39,593 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# 2024-10-13 12:54:40,178 - default - INFO - Fine-tuned model loaded from checkpoint: checkpoints/dicta_il_dictabert/checkpoints_query_passge on epoch: 9
# 2024-10-13 12:54:40,212 - default - INFO - Queries: 9344, Documents: 9344
# 2024-10-13 12:54:40,212 - default - INFO - Encoding queries
# 2024-10-13 12:54:40,214 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:02<00:00,  4.09it/s]
# 2024-10-13 12:54:42,683 - default - INFO - Save embeddings to embeddings/dicta_il_dictabert/TASK_QUERY_DOC/wiki40b_(TASK_TITLE_DOC)/queries.pkl
# 2024-10-13 12:54:42,759 - default - INFO - Encoding documents
# 2024-10-13 12:54:42,760 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:38<00:00,  3.88s/it]
# 2024-10-13 12:55:21,583 - default - INFO - Save embeddings to embeddings/dicta_il_dictabert/TASK_QUERY_DOC/wiki40b_(TASK_TITLE_DOC)/documents.pkl
# 2024-10-13 12:55:21,649 - default - INFO - Creating index
# 2024-10-13 12:55:21,650 - default - INFO - Index 9344 documents
# 2024-10-13 12:55:21,654 - default - INFO - Total documents indexed: 9344
# 2024-10-13 12:55:22,929 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:55:23,006 - default - INFO - Average Precision@1: 0.2507491438356164
# 2024-10-13 12:55:23,006 - default - INFO - Average MRR: 0.2507491438356164
# 2024-10-13 12:55:23,012 - default - INFO - Average NDCG@1: 0.2507491438356164
# 2024-10-13 12:55:23,015 - default - INFO - Results for model: dicta-il/dictabert, task: TASK_QUERY_DOC, dataset_name: wiki40b (TASK_TITLE_DOC),  k=1:
# {'precision': 0.2507491438356164, 'mrr': 0.2507491438356164, 'ndcg': 0.2507491438356164}
# 2024-10-13 12:55:23,019 - default - INFO - Model: dicta-il/dictabert
# 2024-10-13 12:55:23,023 - default - INFO - Task: TASK_QUERY_DOC
# 2024-10-13 12:55:23,024 - default - INFO - Eval dataset Name: synthesized_query_document (TASK_QUERY_DOC)
# Some weights of BertModel were not initialized from the model checkpoint at dicta-il/dictabert and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:55:24,112 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:55:24,137 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# 2024-10-13 12:55:24,714 - default - INFO - Fine-tuned model loaded from checkpoint: checkpoints/dicta_il_dictabert/checkpoints_query_passge on epoch: 9
# 2024-10-13 12:55:24,825 - default - INFO - Queries: 9200, Documents: 9200
# 2024-10-13 12:55:24,827 - default - INFO - Encoding queries
# 2024-10-13 12:55:24,828 - default - INFO - Encode 9200 texts to their embeddings
# Encoding batches: 100%|██████████| 9/9 [00:09<00:00,  1.02s/it]
# 2024-10-13 12:55:34,053 - default - INFO - Save embeddings to embeddings/dicta_il_dictabert/TASK_QUERY_DOC/synthesized_query_document_(TASK_QUERY_DOC)/queries.pkl
# 2024-10-13 12:55:34,111 - default - INFO - Encoding documents
# 2024-10-13 12:55:34,112 - default - INFO - Encode 9200 texts to their embeddings
# Encoding batches: 100%|██████████| 9/9 [00:51<00:00,  5.75s/it]
# 2024-10-13 12:56:25,976 - default - INFO - Save embeddings to embeddings/dicta_il_dictabert/TASK_QUERY_DOC/synthesized_query_document_(TASK_QUERY_DOC)/documents.pkl
# 2024-10-13 12:56:26,038 - default - INFO - Creating index
# 2024-10-13 12:56:26,039 - default - INFO - Index 9200 documents
# 2024-10-13 12:56:26,044 - default - INFO - Total documents indexed: 9200
# 2024-10-13 12:56:27,222 - default - INFO - Evaluating model with k=1
# 2024-10-13 12:56:27,303 - default - INFO - Average Precision@1: 0.6068478260869565
# 2024-10-13 12:56:27,304 - default - INFO - Average MRR: 0.6068478260869565
# 2024-10-13 12:56:27,304 - default - INFO - Average NDCG@1: 0.6068478260869565
# 2024-10-13 12:56:27,305 - default - INFO - Results for model: dicta-il/dictabert, task: TASK_QUERY_DOC, dataset_name: synthesized_query_document (TASK_QUERY_DOC),  k=1:
# {'precision': 0.6068478260869565, 'mrr': 0.6068478260869565, 'ndcg': 0.6068478260869565}
# 2024-10-13 12:56:27,305 - default - INFO - Model: dicta-il/dictabert
# 2024-10-13 12:56:27,306 - default - INFO - Task: TASK_QUERY_DOC
# 2024-10-13 12:56:27,306 - default - INFO - Eval dataset Name: heq (TASK_QUESTION_DOC)
# Some weights of BertModel were not initialized from the model checkpoint at dicta-il/dictabert and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-13 12:56:28,367 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 12:56:28,397 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# ...
# 2024-10-13 13:17:20,527 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [02:51<00:00, 17.17s/it]
# 2024-10-13 13:20:12,307 - default - INFO - Save embeddings to embeddings/intfloat_multilingual_e5_large/TASK_QUESTION_DOC/wiki40b_(TASK_TITLE_DOC)/documents.pkl
# 2024-10-13 13:20:12,415 - default - INFO - Creating index
# 2024-10-13 13:20:12,416 - default - INFO - Index 9344 documents
# 2024-10-13 13:20:12,424 - default - INFO - Total documents indexed: 9344
# 2024-10-13 13:20:13,758 - default - INFO - Evaluating model with k=1
# 2024-10-13 13:20:13,837 - default - INFO - Average Precision@1: 0.588505993150685
# 2024-10-13 13:20:13,838 - default - INFO - Average MRR: 0.588505993150685
# 2024-10-13 13:20:13,841 - default - INFO - Average NDCG@1: 0.588505993150685
# 2024-10-13 13:20:13,846 - default - INFO - Results for model: intfloat/multilingual-e5-large, task: TASK_QUESTION_DOC, dataset_name: wiki40b (TASK_TITLE_DOC),  k=1:
# {'precision': 0.588505993150685, 'mrr': 0.588505993150685, 'ndcg': 0.588505993150685}
# 2024-10-13 13:20:13,850 - default - INFO - Model: intfloat/multilingual-e5-large
# 2024-10-13 13:20:13,852 - default - INFO - Task: TASK_QUESTION_DOC
# 2024-10-13 13:20:13,856 - default - INFO - Eval dataset Name: synthesized_query_document (TASK_QUERY_DOC)
# 2024-10-13 13:20:17,962 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 13:20:18,016 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# 2024-10-13 13:20:19,243 - default - INFO - Fine-tuned model loaded from checkpoint: checkpoints/intfloat_multilingual_e5_large/checkpoints_question_passge on epoch: 9
# 2024-10-13 13:20:19,343 - default - INFO - Queries: 9200, Documents: 9200
# 2024-10-13 13:20:19,344 - default - INFO - Encoding queries
# 2024-10-13 13:20:19,346 - default - INFO - Encode 9200 texts to their embeddings
# Encoding batches: 100%|██████████| 9/9 [00:37<00:00,  4.16s/it]
# 2024-10-13 13:20:56,871 - default - INFO - Save embeddings to embeddings/intfloat_multilingual_e5_large/TASK_QUESTION_DOC/synthesized_query_document_(TASK_QUERY_DOC)/queries.pkl
# 2024-10-13 13:20:56,952 - default - INFO - Encoding documents
# 2024-10-13 13:20:56,953 - default - INFO - Encode 9200 texts to their embeddings
# Encoding batches: 100%|██████████| 9/9 [02:47<00:00, 18.57s/it]
# 2024-10-13 13:23:44,176 - default - INFO - Save embeddings to embeddings/intfloat_multilingual_e5_large/TASK_QUESTION_DOC/synthesized_query_document_(TASK_QUERY_DOC)/documents.pkl
# 2024-10-13 13:23:44,257 - default - INFO - Creating index
# 2024-10-13 13:23:44,258 - default - INFO - Index 9200 documents
# 2024-10-13 13:23:44,263 - default - INFO - Total documents indexed: 9200
# 2024-10-13 13:23:45,427 - default - INFO - Evaluating model with k=1
# 2024-10-13 13:23:45,504 - default - INFO - Average Precision@1: 0.28608695652173916
# 2024-10-13 13:23:45,505 - default - INFO - Average MRR: 0.28608695652173916
# 2024-10-13 13:23:45,510 - default - INFO - Average NDCG@1: 0.28608695652173916
# 2024-10-13 13:23:45,515 - default - INFO - Results for model: intfloat/multilingual-e5-large, task: TASK_QUESTION_DOC, dataset_name: synthesized_query_document (TASK_QUERY_DOC),  k=1:
# {'precision': 0.28608695652173916, 'mrr': 0.28608695652173916, 'ndcg': 0.28608695652173916}
# 2024-10-13 13:23:45,518 - default - INFO - Model: intfloat/multilingual-e5-large
# 2024-10-13 13:23:45,522 - default - INFO - Task: TASK_QUESTION_DOC
# 2024-10-13 13:23:45,526 - default - INFO - Eval dataset Name: heq (TASK_QUESTION_DOC)
# 2024-10-13 13:23:48,367 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 13:23:48,449 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# 2024-10-13 13:23:49,699 - default - INFO - Fine-tuned model loaded from checkpoint: checkpoints/intfloat_multilingual_e5_large/checkpoints_question_passge on epoch: 9
# 2024-10-13 13:23:49,708 - default - INFO - Queries: 238, Documents: 238
# 2024-10-13 13:23:49,710 - default - INFO - Encoding queries
# 2024-10-13 13:23:49,712 - default - INFO - Encode 238 texts to their embeddings
# Encoding batches: 100%|██████████| 1/1 [00:00<00:00,  3.09it/s]
# 2024-10-13 13:23:50,042 - default - INFO - Save embeddings to embeddings/intfloat_multilingual_e5_large/TASK_QUESTION_DOC/heq_(TASK_QUESTION_DOC)/queries.pkl
# 2024-10-13 13:23:50,048 - default - INFO - Encoding documents
# 2024-10-13 13:23:50,050 - default - INFO - Encode 238 texts to their embeddings
# Encoding batches: 100%|██████████| 1/1 [00:04<00:00,  4.42s/it]
# 2024-10-13 13:23:54,492 - default - INFO - Save embeddings to embeddings/intfloat_multilingual_e5_large/TASK_QUESTION_DOC/heq_(TASK_QUESTION_DOC)/documents.pkl
# 2024-10-13 13:23:54,499 - default - INFO - Creating index
# 2024-10-13 13:23:54,500 - default - INFO - Index 238 documents
# 2024-10-13 13:23:54,501 - default - INFO - Total documents indexed: 238
# 2024-10-13 13:23:54,534 - default - INFO - Evaluating model with k=1
# 2024-10-13 13:23:54,537 - default - INFO - Average Precision@1: 0.6764705882352942
# 2024-10-13 13:23:54,538 - default - INFO - Average MRR: 0.6764705882352942
# 2024-10-13 13:23:54,538 - default - INFO - Average NDCG@1: 0.6764705882352942
# 2024-10-13 13:23:54,539 - default - INFO - Results for model: intfloat/multilingual-e5-large, task: TASK_QUESTION_DOC, dataset_name: heq (TASK_QUESTION_DOC),  k=1:
# {'precision': 0.6764705882352942, 'mrr': 0.6764705882352942, 'ndcg': 0.6764705882352942}
# 2024-10-13 13:23:54,539 - default - INFO - Model: intfloat/multilingual-e5-large
# 2024-10-13 13:23:54,540 - default - INFO - Task: TASK_QUESTION_DOC
# 2024-10-13 13:23:54,540 - default - INFO - Eval dataset Name: heq (TASK_TITLE_DOC)
# 2024-10-13 13:23:58,313 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 13:23:58,365 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# 2024-10-13 13:23:59,580 - default - INFO - Fine-tuned model loaded from checkpoint: checkpoints/intfloat_multilingual_e5_large/checkpoints_question_passge on epoch: 9
# 2024-10-13 13:23:59,583 - default - INFO - Queries: 238, Documents: 238
# 2024-10-13 13:23:59,584 - default - INFO - Encoding queries
# 2024-10-13 13:23:59,595 - default - INFO - Encode 238 texts to their embeddings
# Encoding batches: 100%|██████████| 1/1 [00:00<00:00,  3.11it/s]
# 2024-10-13 13:23:59,930 - default - INFO - Save embeddings to embeddings/intfloat_multilingual_e5_large/TASK_QUESTION_DOC/heq_(TASK_TITLE_DOC)/queries.pkl
# 2024-10-13 13:23:59,968 - default - INFO - Encoding documents
# 2024-10-13 13:23:59,974 - default - INFO - Encode 238 texts to their embeddings
# Encoding batches: 100%|██████████| 1/1 [00:04<00:00,  4.43s/it]
# 2024-10-13 13:24:04,426 - default - INFO - Save embeddings to embeddings/intfloat_multilingual_e5_large/TASK_QUESTION_DOC/heq_(TASK_TITLE_DOC)/documents.pkl
# 2024-10-13 13:24:04,433 - default - INFO - Creating index
# 2024-10-13 13:24:04,434 - default - INFO - Index 238 documents
# 2024-10-13 13:24:04,434 - default - INFO - Total documents indexed: 238
# 2024-10-13 13:24:04,468 - default - INFO - Evaluating model with k=1
# 2024-10-13 13:24:04,470 - default - INFO - Average Precision@1: 0.5168067226890757
# 2024-10-13 13:24:04,471 - default - INFO - Average MRR: 0.5168067226890757
# 2024-10-13 13:24:04,471 - default - INFO - Average NDCG@1: 0.5168067226890757
# 2024-10-13 13:24:04,472 - default - INFO - Results for model: intfloat/multilingual-e5-large, task: TASK_QUESTION_DOC, dataset_name: heq (TASK_TITLE_DOC),  k=1:
# {'precision': 0.5168067226890757, 'mrr': 0.5168067226890757, 'ndcg': 0.5168067226890757}
# 2024-10-13 13:24:04,472 - default - INFO - Model: intfloat/multilingual-e5-large
# 2024-10-13 13:24:04,473 - default - INFO - Task: TASK_GENERAL_DOC
# 2024-10-13 13:24:04,473 - default - INFO - Eval dataset Name: wiki40b (TASK_TITLE_DOC)
# 2024-10-13 13:24:07,251 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 13:24:07,303 - default - INFO - Using base model: intfloat/multilingual-e5-large
# 2024-10-13 13:24:07,337 - default - INFO - Queries: 9344, Documents: 9344
# 2024-10-13 13:24:07,338 - default - INFO - Encoding queries
# 2024-10-13 13:24:07,339 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]
# 2024-10-13 13:24:17,563 - default - INFO - Save embeddings to embeddings/intfloat_multilingual_e5_large/TASK_GENERAL_DOC/wiki40b_(TASK_TITLE_DOC)/queries.pkl
# 2024-10-13 13:24:17,638 - default - INFO - Encoding documents
# 2024-10-13 13:24:17,642 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [02:51<00:00, 17.16s/it]
# 2024-10-13 13:27:09,283 - default - INFO - Save embeddings to embeddings/intfloat_multilingual_e5_large/TASK_GENERAL_DOC/wiki40b_(TASK_TITLE_DOC)/documents.pkl
# 2024-10-13 13:27:09,370 - default - INFO - Creating index
# 2024-10-13 13:27:09,371 - default - INFO - Index 9344 documents
# 2024-10-13 13:27:09,375 - default - INFO - Total documents indexed: 9344
# 2024-10-13 13:27:10,704 - default - INFO - Evaluating model with k=1
# 2024-10-13 13:27:10,783 - default - INFO - Average Precision@1: 0.07544948630136987
# 2024-10-13 13:27:10,783 - default - INFO - Average MRR: 0.07544948630136987
# 2024-10-13 13:27:10,784 - default - INFO - Average NDCG@1: 0.07544948630136987
# 2024-10-13 13:27:10,786 - default - INFO - Results for model: intfloat/multilingual-e5-large, task: TASK_GENERAL_DOC, dataset_name: wiki40b (TASK_TITLE_DOC),  k=1:
# {'precision': 0.07544948630136987, 'mrr': 0.07544948630136987, 'ndcg': 0.07544948630136987}
# 2024-10-13 13:27:10,787 - default - INFO - Model: intfloat/multilingual-e5-large
# 2024-10-13 13:27:10,790 - default - INFO - Task: TASK_GENERAL_DOC
# 2024-10-13 13:27:10,792 - default - INFO - Eval dataset Name: synthesized_query_document (TASK_QUERY_DOC)
# 2024-10-13 13:27:14,863 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 13:27:14,924 - default - INFO - Using base model: intfloat/multilingual-e5-large
# 2024-10-13 13:27:15,016 - default - INFO - Queries: 9200, Documents: 9200
# 2024-10-13 13:27:15,017 - default - INFO - Encoding queries
# 2024-10-13 13:27:15,019 - default - INFO - Encode 9200 texts to their embeddings
# Encoding batches: 100%|██████████| 9/9 [00:37<00:00,  4.13s/it]
# 2024-10-13 13:27:52,253 - default - INFO - Save embeddings to embeddings/intfloat_multilingual_e5_large/TASK_GENERAL_DOC/synthesized_query_document_(TASK_QUERY_DOC)/queries.pkl
# 2024-10-13 13:27:52,373 - default - INFO - Encoding documents
# 2024-10-13 13:27:52,374 - default - INFO - Encode 9200 texts to their embeddings
# Encoding batches: 100%|██████████| 9/9 [02:47<00:00, 18.59s/it]
# 2024-10-13 13:30:39,800 - default - INFO - Save embeddings to embeddings/intfloat_multilingual_e5_large/TASK_GENERAL_DOC/synthesized_query_document_(TASK_QUERY_DOC)/documents.pkl
# 2024-10-13 13:30:40,129 - default - INFO - Creating index
# 2024-10-13 13:30:40,130 - default - INFO - Index 9200 documents
# 2024-10-13 13:30:40,135 - default - INFO - Total documents indexed: 9200
# 2024-10-13 13:30:41,326 - default - INFO - Evaluating model with k=1
# 2024-10-13 13:30:41,403 - default - INFO - Average Precision@1: 0.15054347826086956
# 2024-10-13 13:30:41,403 - default - INFO - Average MRR: 0.15054347826086956
# 2024-10-13 13:30:41,404 - default - INFO - Average NDCG@1: 0.15054347826086956
# 2024-10-13 13:30:41,405 - default - INFO - Results for model: intfloat/multilingual-e5-large, task: TASK_GENERAL_DOC, dataset_name: synthesized_query_document (TASK_QUERY_DOC),  k=1:
# {'precision': 0.15054347826086956, 'mrr': 0.15054347826086956, 'ndcg': 0.15054347826086956}
# 2024-10-13 13:30:41,405 - default - INFO - Model: intfloat/multilingual-e5-large
# 2024-10-13 13:30:41,406 - default - INFO - Task: TASK_GENERAL_DOC
# 2024-10-13 13:30:41,406 - default - INFO - Eval dataset Name: heq (TASK_QUESTION_DOC)
# 2024-10-13 13:30:44,688 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 13:30:44,738 - default - INFO - Using base model: intfloat/multilingual-e5-large
# 2024-10-13 13:30:44,747 - default - INFO - Queries: 238, Documents: 238
# 2024-10-13 13:30:44,748 - default - INFO - Encoding queries
# 2024-10-13 13:30:44,750 - default - INFO - Encode 238 texts to their embeddings
# Encoding batches: 100%|██████████| 1/1 [00:00<00:00,  3.13it/s]
# 2024-10-13 13:30:45,077 - default - INFO - Save embeddings to embeddings/intfloat_multilingual_e5_large/TASK_GENERAL_DOC/heq_(TASK_QUESTION_DOC)/queries.pkl
# 2024-10-13 13:30:45,085 - default - INFO - Encoding documents
# 2024-10-13 13:30:45,087 - default - INFO - Encode 238 texts to their embeddings
# Encoding batches: 100%|██████████| 1/1 [00:04<00:00,  4.42s/it]
# 2024-10-13 13:30:49,527 - default - INFO - Save embeddings to embeddings/intfloat_multilingual_e5_large/TASK_GENERAL_DOC/heq_(TASK_QUESTION_DOC)/documents.pkl
# 2024-10-13 13:30:49,535 - default - INFO - Creating index
# 2024-10-13 13:30:49,535 - default - INFO - Index 238 documents
# 2024-10-13 13:30:49,536 - default - INFO - Total documents indexed: 238
# 2024-10-13 13:30:49,569 - default - INFO - Evaluating model with k=1
# 2024-10-13 13:30:49,572 - default - INFO - Average Precision@1: 0.5672268907563025
# 2024-10-13 13:30:49,572 - default - INFO - Average MRR: 0.5672268907563025
# 2024-10-13 13:30:49,573 - default - INFO - Average NDCG@1: 0.5672268907563025
# 2024-10-13 13:30:49,574 - default - INFO - Results for model: intfloat/multilingual-e5-large, task: TASK_GENERAL_DOC, dataset_name: heq (TASK_QUESTION_DOC),  k=1:
# {'precision': 0.5672268907563025, 'mrr': 0.5672268907563025, 'ndcg': 0.5672268907563025}
# 2024-10-13 13:30:49,574 - default - INFO - Model: intfloat/multilingual-e5-large
# 2024-10-13 13:30:49,576 - default - INFO - Task: TASK_GENERAL_DOC
# 2024-10-13 13:30:49,576 - default - INFO - Eval dataset Name: heq (TASK_TITLE_DOC)
# 2024-10-13 13:30:52,362 - default - DEBUG - Adding special tokens: ['[QUERY]', '[DOCUMENT]', '[TASK_QUERY_DOC]', '[TASK_TITLE_DOC]', '[TASK_QUESTION_DOC]']
# 2024-10-13 13:30:52,414 - default - INFO - Using base model: intfloat/multilingual-e5-large
# 2024-10-13 13:30:52,417 - default - INFO - Queries: 238, Documents: 238
# 2024-10-13 13:30:52,418 - default - INFO - Encoding queries
# 2024-10-13 13:30:52,419 - default - INFO - Encode 238 texts to their embeddings
# Encoding batches: 100%|██████████| 1/1 [00:00<00:00,  2.84it/s]
# 2024-10-13 13:30:52,777 - default - INFO - Save embeddings to embeddings/intfloat_multilingual_e5_large/TASK_GENERAL_DOC/heq_(TASK_TITLE_DOC)/queries.pkl
# 2024-10-13 13:30:52,785 - default - INFO - Encoding documents
# 2024-10-13 13:30:52,787 - default - INFO - Encode 238 texts to their embeddings
# Encoding batches: 100%|██████████| 1/1 [00:04<00:00,  4.43s/it]
# 2024-10-13 13:30:57,232 - default - INFO - Save embeddings to embeddings/intfloat_multilingual_e5_large/TASK_GENERAL_DOC/heq_(TASK_TITLE_DOC)/documents.pkl
# 2024-10-13 13:30:57,238 - default - INFO - Creating index
# 2024-10-13 13:30:57,238 - default - INFO - Index 238 documents
# 2024-10-13 13:30:57,239 - default - INFO - Total documents indexed: 238
# 2024-10-13 13:30:57,272 - default - INFO - Evaluating model with k=1
# 2024-10-13 13:30:57,281 - default - INFO - Average Precision@1: 0.22268907563025211
# 2024-10-13 13:30:57,281 - default - INFO - Average MRR: 0.22268907563025211
# 2024-10-13 13:30:57,282 - default - INFO - Average NDCG@1: 0.22268907563025211
# 2024-10-13 13:30:57,282 - default - INFO - Results for model: intfloat/multilingual-e5-large, task: TASK_GENERAL_DOC, dataset_name: heq (TASK_TITLE_DOC),  k=1:
# {'precision': 0.22268907563025211, 'mrr': 0.22268907563025211, 'ndcg': 0.22268907563025211}

# %%
df = pd.DataFrame(eval_results)
# Expand the 'metrics' column (dict) into multiple columns
results_df = df['results'].apply(pd.Series)

# Concatenate the original DataFrame with the expanded metrics columns
df = pd.concat([df.drop('results', axis=1), results_df], axis=1)
df.head(20)
# Out:
#                 model_name               task  \
# 0   onlplab/alephbert-base     TASK_QUERY_DOC
# 1   onlplab/alephbert-base     TASK_QUERY_DOC
# 2   onlplab/alephbert-base     TASK_QUERY_DOC
# 3   onlplab/alephbert-base     TASK_QUERY_DOC
# 4   onlplab/alephbert-base     TASK_TITLE_DOC
# 5   onlplab/alephbert-base     TASK_TITLE_DOC
# 6   onlplab/alephbert-base     TASK_TITLE_DOC
# 7   onlplab/alephbert-base     TASK_TITLE_DOC
# 8   onlplab/alephbert-base  TASK_QUESTION_DOC
# 9   onlplab/alephbert-base  TASK_QUESTION_DOC
# 10  onlplab/alephbert-base  TASK_QUESTION_DOC
# 11  onlplab/alephbert-base  TASK_QUESTION_DOC
# 12  onlplab/alephbert-base   TASK_GENERAL_DOC
# 13  onlplab/alephbert-base   TASK_GENERAL_DOC
# 14  onlplab/alephbert-base   TASK_GENERAL_DOC
# 15  onlplab/alephbert-base   TASK_GENERAL_DOC
# 16      dicta-il/dictabert     TASK_QUERY_DOC
# 17      dicta-il/dictabert     TASK_QUERY_DOC
# 18      dicta-il/dictabert     TASK_QUERY_DOC
# 19      dicta-il/dictabert     TASK_QUERY_DOC
#
#                                    dataset_name  k  precision       mrr  \
# 0                      wiki40b (TASK_TITLE_DOC)  1   0.175407  0.175407
# 1   synthesized_query_document (TASK_QUERY_DOC)  1   0.569022  0.569022
# 2                       heq (TASK_QUESTION_DOC)  1   0.420168  0.420168
# 3                          heq (TASK_TITLE_DOC)  1   0.340336  0.340336
# 4                      wiki40b (TASK_TITLE_DOC)  1   0.652397  0.652397
# 5   synthesized_query_document (TASK_QUERY_DOC)  1   0.171630  0.171630
# 6                       heq (TASK_QUESTION_DOC)  1   0.441176  0.441176
# 7                          heq (TASK_TITLE_DOC)  1   0.382353  0.382353
# 8                      wiki40b (TASK_TITLE_DOC)  1   0.400257  0.400257
# 9   synthesized_query_document (TASK_QUERY_DOC)  1   0.260870  0.260870
# 10                      heq (TASK_QUESTION_DOC)  1   0.647059  0.647059
# 11                         heq (TASK_TITLE_DOC)  1   0.512605  0.512605
# 12                     wiki40b (TASK_TITLE_DOC)  1   0.110445  0.110445
# 13  synthesized_query_document (TASK_QUERY_DOC)  1   0.200978  0.200978
# 14                      heq (TASK_QUESTION_DOC)  1   0.529412  0.529412
# 15                         heq (TASK_TITLE_DOC)  1   0.277311  0.277311
# 16                     wiki40b (TASK_TITLE_DOC)  1   0.250749  0.250749
# 17  synthesized_query_document (TASK_QUERY_DOC)  1   0.606848  0.606848
# 18                      heq (TASK_QUESTION_DOC)  1   0.516807  0.516807
# 19                         heq (TASK_TITLE_DOC)  1   0.457983  0.457983
#
#         ndcg
# 0   0.175407
# 1   0.569022
# 2   0.420168
# 3   0.340336
# 4   0.652397
# 5   0.171630
# 6   0.441176
# 7   0.382353
# 8   0.400257
# 9   0.260870
# 10  0.647059
# 11  0.512605
# 12  0.110445
# 13  0.200978
# 14  0.529412
# 15  0.277311
# 16  0.250749
# 17  0.606848
# 18  0.516807
# 19  0.457983

# %%
# Define custom colors for the bars
colors = ['#d00000', '#dc2f02', '#e85d04', '#f48c06']

# Create a 4x3 grid of subplots (4 tasks, 3 models)
fig, axes = plt.subplots(4, 3, figsize=(13, 25), sharey=True)

# Get the unique tasks and models for iteration
tasks = df['task'].unique()
models = df['model_name'].unique()

# Loop over the tasks (rows) and models (columns)
for i, task in enumerate(tasks):
    for j, model in enumerate(models):
        # Filter data for the given task and model
        subset = df[(df['task'] == task) & (df['model_name'] == model)]
        
        # Select the appropriate subplot
        ax = axes[i, j]

        # Create the bar plot for the given task and model
        sns.barplot(
            data=subset, 
            x='dataset_name', 
            y='precision', 
            ax=ax, 
            palette=colors[:len(subset)]
        )

        # Set title for the subplot
        ax.set_title(f'{model} trained on {task}', fontsize=10)

        # Rotate the x-axis labels by 45 degrees for readability
        ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

        # Set y-axis limits between 0 and 1
        ax.set_ylim(0, 1)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_1249674/896777563.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /tmp/ipykernel_1249674/896777563.py:33: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# /tmp/ipykernel_1249674/896777563.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /tmp/ipykernel_1249674/896777563.py:33: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# /tmp/ipykernel_1249674/896777563.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /tmp/ipykernel_1249674/896777563.py:33: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# /tmp/ipykernel_1249674/896777563.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /tmp/ipykernel_1249674/896777563.py:33: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# /tmp/ipykernel_1249674/896777563.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /tmp/ipykernel_1249674/896777563.py:33: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# /tmp/ipykernel_1249674/896777563.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /tmp/ipykernel_1249674/896777563.py:33: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# /tmp/ipykernel_1249674/896777563.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /tmp/ipykernel_1249674/896777563.py:33: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# /tmp/ipykernel_1249674/896777563.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /tmp/ipykernel_1249674/896777563.py:33: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# /tmp/ipykernel_1249674/896777563.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /tmp/ipykernel_1249674/896777563.py:33: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# /tmp/ipykernel_1249674/896777563.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /tmp/ipykernel_1249674/896777563.py:33: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# /tmp/ipykernel_1249674/896777563.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /tmp/ipykernel_1249674/896777563.py:33: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# /tmp/ipykernel_1249674/896777563.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /tmp/ipykernel_1249674/896777563.py:33: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# %%
eval_results

# %% [markdown]
# ## Model evaluation

# %%
eval_results = dict()

# %% [markdown]
# ### onlplab/alephbert-base

# %%
# %%time

MODEL_NAME = 'onlplab/alephbert-base'
model_name_slug = MODEL_NAME.replace('/', '_').replace('-', '_')

# Logger
model_name_slug = MODEL_NAME.replace('/', '_').replace('-', '_')
log_file = f"./logs/{model_name_slug}/hte_evaluation.log"
logger = setup_logger(log_file)
logger.info("*"*50)

# device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
logger.info(f"Using device: {device}")

# Define model
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModel.from_pretrained(MODEL_NAME)
model = model.to(device)

eval_results[MODEL_NAME] = dict()
checkpoint_paths = ['base', 'checkpoints_01_wiki40b', 'checkpoints_02_synthesized']
for checkpoint_path in checkpoint_paths:
    logger.info(f"Start evaluation on base model: {MODEL_NAME}")
    if checkpoint_path != 'base':
        checkpoint_dir = f"checkpoints/{model_name_slug}/{checkpoint_path}"
        epoch = load_checkpoint(model, optimizer=None, checkpoint_dir=checkpoint_dir, device=device)
        logger.info(f"Fine-tuned model loaded from checkpoint: {checkpoint_dir} on epoch: {epoch}")
    
    # Encode the queries and positive documents into embeddings
    model_id = f'{model_name_slug}_{checkpoint_path}'
    logger.info(f"Encoding queries")
    query_embeddings = get_embeddings(
        queries,
        tokenizer,
        model,
        device,
        batch_size=1024,
        embedding_file_path=f'embeddings/{model_name_slug}/{checkpoint_path or "base"}/queries.pkl'
    )
    logger.info(f"Encoding documents")
    doc_embeddings = get_embeddings(
        documents,
        tokenizer,
        model,
        device,
        batch_size=1024,
        embedding_file_path=f'embeddings/{model_name_slug}/{checkpoint_path or "base"}/documents.pkl'
    )

    # Create the index
    logger.info(f"Creating index")
    index = create_index(doc_embeddings)

    # Evaluate the model with k
    eval_results[MODEL_NAME][checkpoint_path or 'base'] = dict()
    k_values = [1, 10, 100]
    for k in k_values:
        eval_results[MODEL_NAME][checkpoint_path or 'base'][k] = evaluate(query_embeddings, documents, index, k=k)
    
        logger.info(f"Results for model: {MODEL_NAME}, checkpoint: {checkpoint_path or 'base'}, k={k}")
        logger.info(f"{results[MODEL_NAME][checkpoint_path or 'base'][k]}")
# Out:
# 2024-10-06 12:11:16,819 - default - INFO - **************************************************
# 2024-10-06 12:11:16,820 - default - INFO - Using device: cuda
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-10-06 12:11:17,928 - default - INFO - Start evaluation on base model: onlplab/alephbert-base
# 2024-10-06 12:11:17,929 - default - INFO - Encoding queries
# 2024-10-06 12:11:17,931 - default - INFO - Loading embeddings from embeddings/onlplab_alephbert_base/base/queries.pkl
# 2024-10-06 12:11:17,938 - default - INFO - Encoding documents
# 2024-10-06 12:11:17,939 - default - INFO - Loading embeddings from embeddings/onlplab_alephbert_base/base/documents.pkl
# 2024-10-06 12:11:17,952 - default - INFO - Creating index
# 2024-10-06 12:11:17,952 - default - INFO - Index 9344 documents
# 2024-10-06 12:11:17,956 - default - INFO - Total documents indexed: 9344
# 2024-10-06 12:11:20,078 - default - INFO - Evaluating model with k=1
# 2024-10-06 12:11:20,266 - default - INFO - Average Precision@1: 0.07919520547945205
# 2024-10-06 12:11:20,280 - default - INFO - Average MRR: 0.07919520547945205
# 2024-10-06 12:11:20,281 - default - INFO - Average NDCG@1: 0.07919520547945205
# 2024-10-06 12:11:20,283 - default - INFO - Results for model: onlplab/alephbert-base, checkpoint: base, k=1
# 2024-10-06 12:11:20,284 - default - INFO - {'precision': 0.07919520547945205, 'mrr': 0.07919520547945205, 'ndcg': 0.07919520547945205}
# 2024-10-06 12:11:22,344 - default - INFO - Evaluating model with k=10
# 2024-10-06 12:11:22,525 - default - INFO - Average Precision@10: 0.019370719178082196
# 2024-10-06 12:11:22,526 - default - INFO - Average MRR: 0.11173904992933247
# 2024-10-06 12:11:22,527 - default - INFO - Average NDCG@10: 0.131110179327438
# 2024-10-06 12:11:22,527 - default - INFO - Results for model: onlplab/alephbert-base, checkpoint: base, k=10
# 2024-10-06 12:11:22,528 - default - INFO - {'precision': 0.019370719178082196, 'mrr': 0.11173904992933247, 'ndcg': 0.131110179327438}
# 2024-10-06 12:11:24,669 - default - INFO - Evaluating model with k=100
# 2024-10-06 12:11:25,125 - default - INFO - Average Precision@100: 0.003973672945205481
# 2024-10-06 12:11:25,127 - default - INFO - Average MRR: 0.11894573762645631
# 2024-10-06 12:11:25,128 - default - INFO - Average NDCG@100: 0.17179341501477247
# 2024-10-06 12:11:25,129 - default - INFO - Results for model: onlplab/alephbert-base, checkpoint: base, k=100
# 2024-10-06 12:11:25,129 - default - INFO - {'precision': 0.003973672945205481, 'mrr': 0.11894573762645631, 'ndcg': 0.17179341501477247}
# 2024-10-06 12:11:25,130 - default - INFO - Start evaluation on base model: onlplab/alephbert-base
# 2024-10-06 12:11:25,131 - default - INFO - Loading checkpoint checkpoint_epoch_7.pth
# /home/nlp/achimoa/projects/hebrew_text_encoder/src/utils.py:54: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)
# 2024-10-06 12:11:25,929 - default - INFO - Fine-tuned model loaded from checkpoint: checkpoints/onlplab_alephbert_base/checkpoints_01_wiki40b on epoch: 7
# 2024-10-06 12:11:25,930 - default - INFO - Encoding queries
# 2024-10-06 12:11:25,931 - default - INFO - Loading embeddings from embeddings/onlplab_alephbert_base/checkpoints_01_wiki40b/queries.pkl
# 2024-10-06 12:11:25,987 - default - INFO - Encoding documents
# 2024-10-06 12:11:25,989 - default - INFO - Loading embeddings from embeddings/onlplab_alephbert_base/checkpoints_01_wiki40b/documents.pkl
# 2024-10-06 12:11:26,077 - default - INFO - Creating index
# 2024-10-06 12:11:26,080 - default - INFO - Index 9344 documents
# 2024-10-06 12:11:26,112 - default - INFO - Total documents indexed: 9344
# 2024-10-06 12:11:28,201 - default - INFO - Evaluating model with k=1
# 2024-10-06 12:11:28,341 - default - INFO - Average Precision@1: 0.694242294520548
# 2024-10-06 12:11:28,343 - default - INFO - Average MRR: 0.694242294520548
# 2024-10-06 12:11:28,344 - default - INFO - Average NDCG@1: 0.694242294520548
# 2024-10-06 12:11:28,345 - default - INFO - Results for model: onlplab/alephbert-base, checkpoint: checkpoints_01_wiki40b, k=1
# 2024-10-06 12:11:28,346 - default - INFO - {'precision': 0.694242294520548, 'mrr': 0.694242294520548, 'ndcg': 0.694242294520548}
# 2024-10-06 12:11:30,431 - default - INFO - Evaluating model with k=10
# 2024-10-06 12:11:30,598 - default - INFO - Average Precision@10: 0.0834332191780822
# 2024-10-06 12:11:30,600 - default - INFO - Average MRR: 0.7403428819444444
# 2024-10-06 12:11:30,601 - default - INFO - Average NDCG@10: 0.7629982450206266
# 2024-10-06 12:11:30,602 - default - INFO - Results for model: onlplab/alephbert-base, checkpoint: checkpoints_01_wiki40b, k=10
# 2024-10-06 12:11:30,603 - default - INFO - {'precision': 0.0834332191780822, 'mrr': 0.7403428819444444, 'ndcg': 0.7629982450206266}
# 2024-10-06 12:11:32,678 - default - INFO - Evaluating model with k=100
# 2024-10-06 12:11:33,046 - default - INFO - Average Precision@100: 0.009291523972602739
# 2024-10-06 12:11:33,047 - default - INFO - Average MRR: 0.7444338139104716
# 2024-10-06 12:11:33,048 - default - INFO - Average NDCG@100: 0.7830089420980119
# 2024-10-06 12:11:33,049 - default - INFO - Results for model: onlplab/alephbert-base, checkpoint: checkpoints_01_wiki40b, k=100
# 2024-10-06 12:11:33,050 - default - INFO - {'precision': 0.009291523972602739, 'mrr': 0.7444338139104716, 'ndcg': 0.7830089420980119}
# 2024-10-06 12:11:33,050 - default - INFO - Start evaluation on base model: onlplab/alephbert-base
# 2024-10-06 12:11:33,052 - default - INFO - Loading checkpoint checkpoint_epoch_18.pth
# 2024-10-06 12:11:36,784 - default - INFO - Fine-tuned model loaded from checkpoint: checkpoints/onlplab_alephbert_base/checkpoints_02_synthesized on epoch: 18
# 2024-10-06 12:11:36,798 - default - INFO - Encoding queries
# 2024-10-06 12:11:36,801 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:03<00:00,  3.23it/s]
# 2024-10-06 12:11:39,917 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/checkpoints_02_synthesized/queries.pkl
# 2024-10-06 12:11:39,988 - default - INFO - Encoding documents
# 2024-10-06 12:11:39,990 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:43<00:00,  4.37s/it]
# 2024-10-06 12:12:23,756 - default - INFO - Save embeddings to embeddings/onlplab_alephbert_base/checkpoints_02_synthesized/documents.pkl
# 2024-10-06 12:12:23,866 - default - INFO - Creating index
# 2024-10-06 12:12:23,870 - default - INFO - Index 9344 documents
# 2024-10-06 12:12:23,899 - default - INFO - Total documents indexed: 9344
# 2024-10-06 12:12:25,926 - default - INFO - Evaluating model with k=1
# 2024-10-06 12:12:26,052 - default - INFO - Average Precision@1: 0.3372217465753425
# 2024-10-06 12:12:26,064 - default - INFO - Average MRR: 0.3372217465753425
# 2024-10-06 12:12:26,071 - default - INFO - Average NDCG@1: 0.3372217465753425
# 2024-10-06 12:12:26,078 - default - INFO - Results for model: onlplab/alephbert-base, checkpoint: checkpoints_02_synthesized, k=1
# 2024-10-06 12:12:26,085 - default - INFO - {'precision': 0.3372217465753425, 'mrr': 0.3372217465753425, 'ndcg': 0.3372217465753425}
# 2024-10-06 12:12:28,204 - default - INFO - Evaluating model with k=10
# 2024-10-06 12:12:28,399 - default - INFO - Average Precision@10: 0.05421660958904109
# 2024-10-06 12:12:28,403 - default - INFO - Average MRR: 0.39883555698249623
# 2024-10-06 12:12:28,409 - default - INFO - Average NDCG@10: 0.4329217578605432
# 2024-10-06 12:12:28,415 - default - INFO - Results for model: onlplab/alephbert-base, checkpoint: checkpoints_02_synthesized, k=10
# 2024-10-06 12:12:28,420 - default - INFO - {'precision': 0.05421660958904109, 'mrr': 0.39883555698249623, 'ndcg': 0.4329217578605432}
# 2024-10-06 12:12:30,551 - default - INFO - Evaluating model with k=100
# 2024-10-06 12:12:30,950 - default - INFO - Average Precision@100: 0.007460402397260273
# 2024-10-06 12:12:30,954 - default - INFO - Average MRR: 0.4064958536485456
# 2024-10-06 12:12:30,962 - default - INFO - Average NDCG@100: 0.47441514015954916
# 2024-10-06 12:12:30,964 - default - INFO - Results for model: onlplab/alephbert-base, checkpoint: checkpoints_02_synthesized, k=100
# 2024-10-06 12:12:30,968 - default - INFO - {'precision': 0.007460402397260273, 'mrr': 0.4064958536485456, 'ndcg': 0.47441514015954916}
# CPU times: user 21min 26s, sys: 11.5 s, total: 21min 38s
# Wall time: 1min 14s

# %%
# Collect precision@k for each checkpoint
precision_at_k = {checkpoint_path: [eval_results[MODEL_NAME][checkpoint_path or 'base'][k]['precision'] for k in k_values]
                  for checkpoint_path in checkpoint_paths}

# Bar chart visualization
x = np.arange(len(k_values))  # the label locations
width = 0.2  # the width of the bars

fig, ax = plt.subplots()

# Colors for the bars
colors = ['#d62828', '#f77f00', '#fcbf49']

# Plotting bars for each checkpoint
for i, (checkpoint, precisions) in enumerate(precision_at_k.items()):
    ax.bar(x + i * width, precisions, width, label=checkpoint, color=colors[i])

# Add labels, title, and custom x-axis tick labels, etc.
ax.set_xlabel('K Values')
ax.set_ylabel('Precision@K')
ax.set_title(f'Precision@K Comparison for {MODEL_NAME}')
ax.set_xticks(x + width / 2)
ax.set_xticklabels(k_values)
ax.legend()

# Display the chart
plt.show()

# %% [markdown]
# ### intfloat/multilingual-e5-large

# %%
# %%time

MODEL_NAME = 'intfloat/multilingual-e5-large'
model_name_slug = MODEL_NAME.replace('/', '_').replace('-', '_')
checkpoint_paths = ['base', 'checkpoints_01_wiki40b', 'checkpoints_02_synthesized']

# Logger
model_name_slug = MODEL_NAME.replace('/', '_').replace('-', '_')
log_file = f"./logs/{model_name_slug}/hte_evaluation.log"
logger = setup_logger(log_file)
logger.info("*"*50)

# device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
logger.info(f"Using device: {device}")

# Define model
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModel.from_pretrained(MODEL_NAME)
model = model.to(device)

eval_results[MODEL_NAME] = dict()
for checkpoint_path in checkpoint_paths:
    logger.info(f"Start evaluation on base model: {MODEL_NAME}")
    if checkpoint_path is not 'base':
        checkpoint_dir = f"checkpoints/{model_name_slug}/{checkpoint_path}"
        epoch = load_checkpoint(model, optimizer=None, checkpoint_dir=checkpoint_dir, device=device)
        logger.info(f"Fine-tuned model loaded from checkpoint: {checkpoint_dir} on epoch: {epoch}")
    
    # Encode the queries and positive documents into embeddings
    model_id = f'{model_name_slug}_{checkpoint_path}'
    logger.info(f"Encoding queries")
    query_embeddings = get_embeddings(
        queries,
        tokenizer,
        model,
        device,
        batch_size=1024,
        embedding_file_path=f'embeddings/{model_name_slug}/{checkpoint_path or "base"}/queries.pkl'
    )
    logger.info(f"Encoding documents")
    doc_embeddings = get_embeddings(
        documents,
        tokenizer,
        model,
        device,
        batch_size=1024,
        embedding_file_path=f'embeddings/{model_name_slug}/{checkpoint_path or "base"}/documents.pkl'
    )

    # Create the index
    logger.info(f"Creating index")
    index = create_index(doc_embeddings)

    # Evaluate the model with k
    eval_results[MODEL_NAME][checkpoint_path or 'base'] = dict()
    k_values = [1, 10, 100]
    for k in k_values:
        eval_results[MODEL_NAME][checkpoint_path or 'base'][k] = evaluate(query_embeddings, documents, index, k=k)
    
        logger.info(f"Results for model: {MODEL_NAME}, checkpoint: {checkpoint_path or 'base'}, k={k}")
        logger.info(f"{results[MODEL_NAME][checkpoint_path or 'base'][k]}")
# Out:
# <timed exec>:23: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# 2024-10-06 12:14:13,717 - default - INFO - **************************************************
# 2024-10-06 12:14:13,718 - default - INFO - Using device: cuda
# 2024-10-06 12:14:17,251 - default - INFO - Start evaluation on base model: intfloat/multilingual-e5-large
# 2024-10-06 12:14:17,252 - default - INFO - Encoding queries
# 2024-10-06 12:14:17,254 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:11<00:00,  1.11s/it]
# 2024-10-06 12:14:28,457 - default - INFO - Save embeddings to embeddings/intfloat_multilingual_e5_large/base/queries.pkl
# 2024-10-06 12:14:28,541 - default - INFO - Encoding documents
# 2024-10-06 12:14:28,542 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|████████████████████████████████████████████████████████████████████████████████████████| 10/10 [02:53<00:00, 17.31s/it]
# 2024-10-06 12:17:21,672 - default - INFO - Save embeddings to embeddings/intfloat_multilingual_e5_large/base/documents.pkl
# 2024-10-06 12:17:21,797 - default - INFO - Creating index
# 2024-10-06 12:17:21,798 - default - INFO - Index 9344 documents
# 2024-10-06 12:17:21,813 - default - INFO - Total documents indexed: 9344
# 2024-10-06 12:17:25,083 - default - INFO - Evaluating model with k=1
# 2024-10-06 12:17:25,210 - default - INFO - Average Precision@1: 0.5255779109589042
# 2024-10-06 12:17:25,210 - default - INFO - Average MRR: 0.5255779109589042
# 2024-10-06 12:17:25,212 - default - INFO - Average NDCG@1: 0.5255779109589042
# 2024-10-06 12:17:25,213 - default - INFO - Results for model: intfloat/multilingual-e5-large, checkpoint: base, k=1
# 2024-10-06 12:17:25,214 - default - INFO - {'precision': 0.5255779109589042, 'mrr': 0.5255779109589042, 'ndcg': 0.5255779109589042}
# 2024-10-06 12:17:27,337 - default - INFO - Evaluating model with k=10
# 2024-10-06 12:17:27,497 - default - INFO - Average Precision@10: 0.0723994006849315
# 2024-10-06 12:17:27,498 - default - INFO - Average MRR: 0.5880283502527723
# 2024-10-06 12:17:27,501 - default - INFO - Average NDCG@10: 0.6205824538365539
# 2024-10-06 12:17:27,503 - default - INFO - Results for model: intfloat/multilingual-e5-large, checkpoint: base, k=10
# 2024-10-06 12:17:27,505 - default - INFO - {'precision': 0.0723994006849315, 'mrr': 0.5880283502527723, 'ndcg': 0.6205824538365539}
# 2024-10-06 12:17:29,733 - default - INFO - Evaluating model with k=100
# 2024-10-06 12:17:30,084 - default - INFO - Average Precision@100: 0.008705051369863012
# 2024-10-06 12:17:30,086 - default - INFO - Average MRR: 0.5937941133265505
# 2024-10-06 12:17:30,091 - default - INFO - Average NDCG@100: 0.6508392307549414
# 2024-10-06 12:17:30,094 - default - INFO - Results for model: intfloat/multilingual-e5-large, checkpoint: base, k=100
# 2024-10-06 12:17:30,096 - default - INFO - {'precision': 0.008705051369863012, 'mrr': 0.5937941133265505, 'ndcg': 0.6508392307549414}
# 2024-10-06 12:17:30,099 - default - INFO - Start evaluation on base model: intfloat/multilingual-e5-large
# 2024-10-06 12:17:30,118 - default - INFO - Loading checkpoint checkpoint_epoch_8.pth
# /home/nlp/achimoa/projects/hebrew_text_encoder/src/utils.py:54: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)
# 2024-10-06 12:17:32,890 - default - INFO - Fine-tuned model loaded from checkpoint: checkpoints/intfloat_multilingual_e5_large/checkpoints_01_wiki40b on epoch: 8
# 2024-10-06 12:17:32,892 - default - INFO - Encoding queries
# 2024-10-06 12:17:32,893 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:10<00:00,  1.09s/it]
# 2024-10-06 12:17:43,854 - default - INFO - Save embeddings to embeddings/intfloat_multilingual_e5_large/checkpoints_01_wiki40b/queries.pkl
# 2024-10-06 12:17:43,978 - default - INFO - Encoding documents
# 2024-10-06 12:17:43,982 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|████████████████████████████████████████████████████████████████████████████████████████| 10/10 [02:53<00:00, 17.31s/it]
# 2024-10-06 12:20:37,127 - default - INFO - Save embeddings to embeddings/intfloat_multilingual_e5_large/checkpoints_01_wiki40b/documents.pkl
# 2024-10-06 12:20:37,243 - default - INFO - Creating index
# 2024-10-06 12:20:37,245 - default - INFO - Index 9344 documents
# 2024-10-06 12:20:37,258 - default - INFO - Total documents indexed: 9344
# 2024-10-06 12:20:39,330 - default - INFO - Evaluating model with k=1
# 2024-10-06 12:20:39,467 - default - INFO - Average Precision@1: 0.7272046232876712
# 2024-10-06 12:20:39,469 - default - INFO - Average MRR: 0.7272046232876712
# 2024-10-06 12:20:39,471 - default - INFO - Average NDCG@1: 0.7272046232876712
# 2024-10-06 12:20:39,474 - default - INFO - Results for model: intfloat/multilingual-e5-large, checkpoint: checkpoints_01_wiki40b, k=1
# 2024-10-06 12:20:39,476 - default - INFO - {'precision': 0.7272046232876712, 'mrr': 0.7272046232876712, 'ndcg': 0.7272046232876712}
# 2024-10-06 12:20:41,437 - default - INFO - Evaluating model with k=10
# 2024-10-06 12:20:41,617 - default - INFO - Average Precision@10: 0.0863548801369863
# 2024-10-06 12:20:41,618 - default - INFO - Average MRR: 0.7719683457001522
# 2024-10-06 12:20:41,619 - default - INFO - Average NDCG@10: 0.7940663006630172
# 2024-10-06 12:20:41,620 - default - INFO - Results for model: intfloat/multilingual-e5-large, checkpoint: checkpoints_01_wiki40b, k=10
# 2024-10-06 12:20:41,621 - default - INFO - {'precision': 0.0863548801369863, 'mrr': 0.7719683457001522, 'ndcg': 0.7940663006630172}
# 2024-10-06 12:20:43,820 - default - INFO - Evaluating model with k=100
# 2024-10-06 12:20:44,157 - default - INFO - Average Precision@100: 0.009459546232876712
# 2024-10-06 12:20:44,171 - default - INFO - Average MRR: 0.7753610798050543
# 2024-10-06 12:20:44,172 - default - INFO - Average NDCG@100: 0.8112739710012993
# 2024-10-06 12:20:44,174 - default - INFO - Results for model: intfloat/multilingual-e5-large, checkpoint: checkpoints_01_wiki40b, k=100
# 2024-10-06 12:20:44,175 - default - INFO - {'precision': 0.009459546232876712, 'mrr': 0.7753610798050543, 'ndcg': 0.8112739710012993}
# 2024-10-06 12:20:44,176 - default - INFO - Start evaluation on base model: intfloat/multilingual-e5-large
# 2024-10-06 12:20:44,178 - default - INFO - Loading checkpoint checkpoint_epoch_16.pth
# 2024-10-06 12:21:00,917 - default - INFO - Fine-tuned model loaded from checkpoint: checkpoints/intfloat_multilingual_e5_large/checkpoints_02_synthesized on epoch: 16
# 2024-10-06 12:21:00,926 - default - INFO - Encoding queries
# 2024-10-06 12:21:00,929 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:11<00:00,  1.12s/it]
# 2024-10-06 12:21:12,148 - default - INFO - Save embeddings to embeddings/intfloat_multilingual_e5_large/checkpoints_02_synthesized/queries.pkl
# 2024-10-06 12:21:12,228 - default - INFO - Encoding documents
# 2024-10-06 12:21:12,231 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|████████████████████████████████████████████████████████████████████████████████████████| 10/10 [02:52<00:00, 17.28s/it]
# 2024-10-06 12:24:05,107 - default - INFO - Save embeddings to embeddings/intfloat_multilingual_e5_large/checkpoints_02_synthesized/documents.pkl
# 2024-10-06 12:24:05,204 - default - INFO - Creating index
# 2024-10-06 12:24:05,205 - default - INFO - Index 9344 documents
# 2024-10-06 12:24:05,223 - default - INFO - Total documents indexed: 9344
# 2024-10-06 12:24:07,318 - default - INFO - Evaluating model with k=1
# 2024-10-06 12:24:07,445 - default - INFO - Average Precision@1: 0.3876284246575342
# 2024-10-06 12:24:07,448 - default - INFO - Average MRR: 0.3876284246575342
# 2024-10-06 12:24:07,449 - default - INFO - Average NDCG@1: 0.3876284246575342
# 2024-10-06 12:24:07,451 - default - INFO - Results for model: intfloat/multilingual-e5-large, checkpoint: checkpoints_02_synthesized, k=1
# 2024-10-06 12:24:07,452 - default - INFO - {'precision': 0.3876284246575342, 'mrr': 0.3876284246575342, 'ndcg': 0.3876284246575342}
# 2024-10-06 12:24:09,454 - default - INFO - Evaluating model with k=10
# 2024-10-06 12:24:09,643 - default - INFO - Average Precision@10: 0.05950342465753425
# 2024-10-06 12:24:09,645 - default - INFO - Average MRR: 0.452432381699826
# 2024-10-06 12:24:09,654 - default - INFO - Average NDCG@10: 0.48655765897551595
# 2024-10-06 12:24:09,656 - default - INFO - Results for model: intfloat/multilingual-e5-large, checkpoint: checkpoints_02_synthesized, k=10
# 2024-10-06 12:24:09,657 - default - INFO - {'precision': 0.05950342465753425, 'mrr': 0.452432381699826, 'ndcg': 0.48655765897551595}
# 2024-10-06 12:24:11,916 - default - INFO - Evaluating model with k=100
# 2024-10-06 12:24:12,313 - default - INFO - Average Precision@100: 0.007790025684931506
# 2024-10-06 12:24:12,314 - default - INFO - Average MRR: 0.4595718037620127
# 2024-10-06 12:24:12,315 - default - INFO - Average NDCG@100: 0.524334172446135
# 2024-10-06 12:24:12,316 - default - INFO - Results for model: intfloat/multilingual-e5-large, checkpoint: checkpoints_02_synthesized, k=100
# 2024-10-06 12:24:12,316 - default - INFO - {'precision': 0.007790025684931506, 'mrr': 0.4595718037620127, 'ndcg': 0.524334172446135}
# CPU times: user 31min 55s, sys: 27.4 s, total: 32min 23s
# Wall time: 9min 58s

# %%
# Collect precision@k for each checkpoint
precision_at_k = {checkpoint_path: [eval_results[MODEL_NAME][checkpoint_path or 'base'][1]['precision'] for k in k_values]
                  for checkpoint_path in checkpoint_paths}

# Bar chart visualization
x = np.arange(len(k_values))  # the label locations
width = 0.2  # the width of the bars

fig, ax = plt.subplots()

# Colors for the bars
colors = ['#d62828', '#f77f00', '#fcbf49']

# Plotting bars for each checkpoint
for i, (checkpoint, precisions) in enumerate(precision_at_k.items()):
    ax.bar(x + i * width, precisions, width, label=checkpoint, color=colors[i])

# Add labels, title, and custom x-axis tick labels, etc.
ax.set_xlabel('K Values')
ax.set_ylabel('Precision@K')
ax.set_title(f'Precision@K Comparison for {MODEL_NAME}')
ax.set_xticks(x + width / 2)
ax.set_xticklabels(k_values)
ax.legend()

# Display the chart
plt.show()

# %%
# Transform the data into a DataFrame for plotting
data = []
for model_name, checkpoints in eval_results.items():
    for checkpoint, metrics in checkpoints.items():
        for k, results in metrics.items():
            if k == 1:  # Focus on k=1 for these charts
                data.append({
                    'model_name': model_name,
                    'checkpoint': checkpoint,
                    'precision': results['precision'],
                    'mrr': results['mrr'],
                    'ndcg': results['ndcg']
                })

df = pd.DataFrame(data)

# Define the colors you wish to use
colors = ['#d62828', '#f77f00', '#fcbf49']

# Plotting precision@1, MRR@1, and nDCG@1 for different models (model names as the x-axis)
metrics = ['precision', 'mrr', 'ndcg']
y_labels = ['Precision', 'MRR', 'nDGC']

# Set the figure size slightly smaller and slim the bars
fig, axes = plt.subplots(1, 3, figsize=(15, 8), sharey=True)  # Slightly smaller figure

for i, (metric, y_label) in enumerate(zip(metrics, y_labels)):
    sns.barplot(x='model_name', y=metric, hue='checkpoint', data=df, ax=axes[i], palette=colors)
    axes[i].set_title(f'{y_label}@1')
    axes[i].set_ylabel("")
    axes[i].set_ylim(0, 1.0)  # Set y-axis limit to 1.0
    axes[i].set_xticks(range(len(df['model_name'].unique())))
    axes[i].set_xticklabels(df['model_name'].unique(), rotation=45, ha='right')

# Adjust the layout so the legend doesn't overlap the plot
plt.tight_layout()  # Adjust the right margin to make space for the legend
plt.show()

# %%
df
# Out:
#                        model_name                  checkpoint  precision  \
# 0          onlplab/alephbert-base                        base   0.079195
# 1          onlplab/alephbert-base      checkpoints_01_wiki40b   0.694242
# 2          onlplab/alephbert-base  checkpoints_02_synthesized   0.337222
# 3  intfloat/multilingual-e5-large                        base   0.525578
# 4  intfloat/multilingual-e5-large      checkpoints_01_wiki40b   0.727205
# 5  intfloat/multilingual-e5-large  checkpoints_02_synthesized   0.387628
#
#         mrr      ndcg
# 0  0.079195  0.079195
# 1  0.694242  0.694242
# 2  0.337222  0.337222
# 3  0.525578  0.525578
# 4  0.727205  0.727205
# 5  0.387628  0.387628

# %%
eval_results
# Out:
# {'onlplab/alephbert-base': {'base': {1: {'precision': 0.07919520547945205,
#     'mrr': 0.07919520547945205,
#     'ndcg': 0.07919520547945205},
#    10: {'precision': 0.019370719178082196,
#     'mrr': 0.11173904992933247,
#     'ndcg': 0.131110179327438},
#    100: {'precision': 0.003973672945205481,
#     'mrr': 0.11894573762645631,
#     'ndcg': 0.17179341501477247}},
#   'checkpoints_01_wiki40b': {1: {'precision': 0.694242294520548,
#     'mrr': 0.694242294520548,
#     'ndcg': 0.694242294520548},
#    10: {'precision': 0.0834332191780822,
#     'mrr': 0.7403428819444444,
#     'ndcg': 0.7629982450206266},
#    100: {'precision': 0.009291523972602739,
#     'mrr': 0.7444338139104716,
#     'ndcg': 0.7830089420980119}},
#   'checkpoints_02_synthesized': {1: {'precision': 0.3372217465753425,
#     'mrr': 0.3372217465753425,
#     'ndcg': 0.3372217465753425},
#    10: {'precision': 0.05421660958904109,
#     'mrr': 0.39883555698249623,
#     'ndcg': 0.4329217578605432},
#    100: {'precision': 0.007460402397260273,
#     'mrr': 0.4064958536485456,
#     'ndcg': 0.47441514015954916}}},
#  'intfloat/multilingual-e5-large': {'base': {1: {'precision': 0.5255779109589042,
#     'mrr': 0.5255779109589042,
#     'ndcg': 0.5255779109589042},
#    10: {'precision': 0.0723994006849315,
#     'mrr': 0.5880283502527723,
#     'ndcg': 0.6205824538365539},
#    100: {'precision': 0.008705051369863012,
#     'mrr': 0.5937941133265505,
#     'ndcg': 0.6508392307549414}},
#   'checkpoints_01_wiki40b': {1: {'precision': 0.7272046232876712,
#     'mrr': 0.7272046232876712,
#     'ndcg': 0.7272046232876712},
#    10: {'precision': 0.0863548801369863,
#     'mrr': 0.7719683457001522,
#     'ndcg': 0.7940663006630172},
#    100: {'precision': 0.009459546232876712,
#     'mrr': 0.7753610798050543,
#     'ndcg': 0.8112739710012993}},
#   'checkpoints_02_synthesized': {1: {'precision': 0.3876284246575342,
#     'mrr': 0.3876284246575342,
#     'ndcg': 0.3876284246575342},
#    10: {'precision': 0.05950342465753425,
#     'mrr': 0.452432381699826,
#     'ndcg': 0.48655765897551595},
#    100: {'precision': 0.007790025684931506,
#     'mrr': 0.4595718037620127,
#     'ndcg': 0.524334172446135}}}}

# %%
dataset_name = 'synthesized_query_document'
logger.info(f"Switching to new dataset: {dataset_name}")
dataset = transform_dataset(dataset_name, data_folder_path='./data/synthetic_data_202409')
# Out:
# 2024-10-06 14:16:09,453 - default - INFO - Switching to new dataset: synthesized_query_document
# 2024-10-06 14:16:09,458 - default - INFO - Transforming synthesized dataset
# 2024-10-06 14:16:09,460 - default - INFO - Loading synthesize query document dataset from {data_folder_path}
# Loading data files:   0%|                                                                                               | 0/13 [00:00<?, ?it/s]2024-10-06 14:16:09,467 - default - DEBUG - Loading data from synthetic_data_20240906_0018.pkl
# Loading data files:   8%|██████▋                                                                                | 1/13 [00:00<00:01,  8.78it/s]2024-10-06 14:16:09,581 - default - DEBUG - Loading data from synthetic_data_20240920_0557.pkl
# 2024-10-06 14:16:09,585 - default - DEBUG - Loading data from synthetic_data_20240924_1958.pkl
# 2024-10-06 14:16:09,662 - default - DEBUG - Loading data from synthetic_data_20240924_1959.pkl
# Loading data files:  31%|██████████████████████████▊                                                            | 4/13 [00:00<00:00, 13.60it/s]2024-10-06 14:16:09,774 - default - DEBUG - Loading data from synthetic_data_20240924_2023.pkl
# 2024-10-06 14:16:09,889 - default - DEBUG - Loading data from synthetic_data_20240930_1838.pkl
# Loading data files:  46%|████████████████████████████████████████▏                                              | 6/13 [00:00<00:00, 10.93it/s]2024-10-06 14:16:10,005 - default - DEBUG - Loading data from synthetic_data_20240930_1845.pkl
# 2024-10-06 14:16:10,132 - default - DEBUG - Loading data from synthetic_data_20240930_1846.pkl
# Loading data files:  62%|█████████████████████████████████████████████████████▌                                 | 8/13 [00:00<00:00, 10.13it/s]2024-10-06 14:16:10,224 - default - DEBUG - Loading data from synthetic_data_20240930_1847.pkl
# 2024-10-06 14:16:10,301 - default - DEBUG - Loading data from synthetic_data_20241001_1259.pkl
# Loading data files:  77%|██████████████████████████████████████████████████████████████████▏                   | 10/13 [00:00<00:00, 11.02it/s]2024-10-06 14:16:10,376 - default - DEBUG - Loading data from synthetic_data_20241001_1302.pkl
# 2024-10-06 14:16:10,430 - default - DEBUG - Loading data from synthetic_data_20241001_1303.pkl
# Loading data files:  92%|███████████████████████████████████████████████████████████████████████████████▍      | 12/13 [00:01<00:00, 12.40it/s]2024-10-06 14:16:10,498 - default - DEBUG - Loading data from synthetic_data_20241001_1418.pkl
# Loading data files: 100%|██████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:01<00:00, 11.88it/s]
# 2024-10-06 14:16:12,257 - default - INFO - Done transforming synthesized dataset

# %%
dataset['train'][0]
# Out:
# {'anchor_text': 'query: איך להתמודד עם אתגרים חוקיים ואתיים בנוגע לזכויות יוצרים של יצירות ספרותיות דיגיטליות כתוצאה מהתפתחות הטכנולוגיות החדשות?',
#  'positive_text': 'document: עם התפתחות האינטרנט והטכנולוגיות הדיגיטליות, התעוררו אתגרים חדשים בתחום זכויות היוצרים של יצירות ספרותיות דיגיטליות. מצד אחד, הגישה הנוחה ליצירות אלה מאפשרת להפיץ ידע ולקדם חופש ביטוי. מצד שני, קיימת סכנה לפגיעה בזכויות היוצרים של הסופרים והמו"לים. חשוב לאזן בין גישה חופשית לתכנים לבין הגנה על זכויות הקניין הרוחני. חוקים ורגולציות חדשים נדרשים כדי להתמודד עם האתגרים המשתנים, תוך שמירה על עקרונות של הגינות, חופש ביטוי וקידום הידע. יש לעודד טכנולוגיות שמכבדות זכויות יוצרים ומאפשרות תגמול הוגן לסופרים ויוצרים.',
#  'negative_text': 'document: הטכנולוגיות החדשות גורמות לאנשים להעריך יותר את היצירה הספרותית ולהכיר בערך התרבותי והאינטלקטואלי של הסופרים. למרות ההזדמנויות לשיתוף לא חוקי של יצירות ספרותיות באינטרנט, רוב האנשים מבינים את החשיבות של הגנה על זכויות יוצרים. ניתן להשתמש באמצעים טכנולוגיים כדי לנטר ולמנוע הפצה בלתי חוקית של ספרים. מדינות רבות גם מחמירות את החוקים בנושא זה. כך מובטחת הגנה מרבית על הקניין הרוחני של הסופרים.'}

# %%
# %%time



for epoch in range(1):
    # Load the latest checkpoint if available and resume training
    logger.info(f"Loading checkpoint at {epoch if epoch is not None else 'last'} epoch")
    checkpoint_dir = "checkpoints/{model_name_slug}/checkpoints_01_wiki40b"
    start_epoch = load_checkpoint(model, optimizer=None, checkpoint_dir=checkpoint_dir, device=device, epoch=epoch)

    # Evaluate the model with k
    for k in [10]:
        logger.info(f"Evaluating model with k={k}")
        evaluate(queries, documents, tokenizer, model, device, k=k)
# Out:
# 2024-10-02 00:16:20,823 - default - INFO - Loading checkpoint at 0 epoch
# 2024-10-02 00:16:20,825 - default - INFO - No checkpoint found. Starting from scratch.
# 2024-10-02 00:16:20,827 - default - INFO - Evaluating model with k=10
# 2024-10-02 00:16:20,828 - default - INFO - Encoding queries
# 2024-10-02 00:16:20,828 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:02<00:00,  3.78it/s]
# 2024-10-02 00:16:23,518 - default - INFO - Encoding documents
# 2024-10-02 00:16:23,519 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:43<00:00,  4.33s/it]
# 2024-10-02 00:17:06,869 - default - INFO - Index 9344 documents
# 2024-10-02 00:17:06,874 - default - INFO - Total documents indexed: 9344
# 2024-10-02 00:17:06,974 - default - INFO - Evaluating model with k=10
# 2024-10-02 00:17:07,066 - default - INFO - Average Precision@10: 0.027686215753424656
# 2024-10-02 00:17:07,066 - default - INFO - Average MRR: 0.17367782907969123
# 2024-10-02 00:17:07,067 - default - INFO - Average NDCG@10: 0.19813907654778248
# CPU times: user 1min 28s, sys: 5.55 s, total: 1min 33s
# Wall time: 46.3 s

# %%
# %%time

# Get the queries and their related documents
queries = dataset['test']['anchor_text']
documents = dataset['test']['positive_text']

for epoch in range(10):
    # Load the latest checkpoint if available and resume training
    logger.info(f"Loading checkpoint at {epoch if epoch is not None else 'last'} epoch")
    checkpoint_dir = "checkpoints/checkpoints_01_wiki40b"
    start_epoch = load_checkpoint(model, optimizer=None, checkpoint_dir=checkpoint_dir, device=device, epoch=epoch)

    # Evaluate the model with k
    for k in [10]:
        logger.info(f"Evaluating model with k={k}")
        evaluate(queries, documents, k=k)
# Out:
# 2024-10-01 15:09:48,321 - default - INFO - Loading checkpoint at 0 epoch
# 2024-10-01 15:09:48,324 - default - INFO - Loading checkpoint checkpoint_epoch_0.pth
# <ipython-input-42-5c9070339655>:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)
# 2024-10-01 15:10:26,867 - default - INFO - Evaluating model with k=10
# 2024-10-01 15:10:26,869 - default - INFO - Encoding queries
# 2024-10-01 15:10:26,871 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:03<00:00,  3.22it/s]
# 2024-10-01 15:10:29,991 - default - INFO - Encoding documents
# 2024-10-01 15:10:29,992 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:52<00:00,  5.28s/it]
# 2024-10-01 15:11:22,782 - default - INFO - Index 9344 documents
# 2024-10-01 15:11:22,793 - default - INFO - Total documents indexed: 9344
# 2024-10-01 15:11:24,785 - default - INFO - Evaluating model with k=10
# 2024-10-01 15:11:24,912 - default - INFO - Average Precision@10: 0.08351883561643836
# 2024-10-01 15:11:24,914 - default - INFO - Average MRR: 0.7214117963823657
# 2024-10-01 15:11:24,915 - default - INFO - Average NDCG@10: 0.7489043849907079
# 2024-10-01 15:11:24,917 - default - INFO - Loading checkpoint at 1 epoch
# 2024-10-01 15:11:24,919 - default - INFO - Loading checkpoint checkpoint_epoch_1.pth
# 2024-10-01 15:11:54,523 - default - INFO - Evaluating model with k=10
# 2024-10-01 15:11:54,525 - default - INFO - Encoding queries
# 2024-10-01 15:11:54,527 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:03<00:00,  3.23it/s]
# 2024-10-01 15:11:57,639 - default - INFO - Encoding documents
# 2024-10-01 15:11:57,641 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:52<00:00,  5.27s/it]
# 2024-10-01 15:12:50,406 - default - INFO - Index 9344 documents
# 2024-10-01 15:12:50,417 - default - INFO - Total documents indexed: 9344
# 2024-10-01 15:12:52,380 - default - INFO - Evaluating model with k=10
# 2024-10-01 15:12:52,504 - default - INFO - Average Precision@10: 0.08320847602739727
# 2024-10-01 15:12:52,505 - default - INFO - Average MRR: 0.7061988679604262
# 2024-10-01 15:12:52,507 - default - INFO - Average NDCG@10: 0.7366592133912251
# 2024-10-01 15:12:52,508 - default - INFO - Loading checkpoint at 2 epoch
# 2024-10-01 15:12:52,510 - default - INFO - Loading checkpoint checkpoint_epoch_2.pth
# 2024-10-01 15:13:29,619 - default - INFO - Evaluating model with k=10
# 2024-10-01 15:13:29,621 - default - INFO - Encoding queries
# 2024-10-01 15:13:29,623 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:03<00:00,  3.06it/s]
# 2024-10-01 15:13:32,912 - default - INFO - Encoding documents
# 2024-10-01 15:13:32,913 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:52<00:00,  5.28s/it]
# 2024-10-01 15:14:25,716 - default - INFO - Index 9344 documents
# 2024-10-01 15:14:25,727 - default - INFO - Total documents indexed: 9344
# 2024-10-01 15:14:27,665 - default - INFO - Evaluating model with k=10
# 2024-10-01 15:14:27,789 - default - INFO - Average Precision@10: 0.08276969178082191
# 2024-10-01 15:14:27,791 - default - INFO - Average MRR: 0.6918720866628615
# 2024-10-01 15:14:27,793 - default - INFO - Average NDCG@10: 0.7246777900488773
# 2024-10-01 15:14:27,795 - default - INFO - Loading checkpoint at 3 epoch
# 2024-10-01 15:14:27,797 - default - INFO - Loading checkpoint checkpoint_epoch_3.pth
# 2024-10-01 15:15:01,409 - default - INFO - Evaluating model with k=10
# 2024-10-01 15:15:01,410 - default - INFO - Encoding queries
# 2024-10-01 15:15:01,413 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:03<00:00,  3.23it/s]
# 2024-10-01 15:15:04,529 - default - INFO - Encoding documents
# 2024-10-01 15:15:04,530 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:52<00:00,  5.28s/it]
# 2024-10-01 15:15:57,319 - default - INFO - Index 9344 documents
# 2024-10-01 15:15:57,329 - default - INFO - Total documents indexed: 9344
# 2024-10-01 15:15:59,293 - default - INFO - Evaluating model with k=10
# 2024-10-01 15:15:59,421 - default - INFO - Average Precision@10: 0.08225599315068492
# 2024-10-01 15:15:59,423 - default - INFO - Average MRR: 0.6791293368803
# 2024-10-01 15:15:59,425 - default - INFO - Average NDCG@10: 0.7137571446228742
# 2024-10-01 15:15:59,426 - default - INFO - Loading checkpoint at 4 epoch
# 2024-10-01 15:15:59,429 - default - INFO - Loading checkpoint checkpoint_epoch_4.pth
# 2024-10-01 15:16:30,035 - default - INFO - Evaluating model with k=10
# 2024-10-01 15:16:30,037 - default - INFO - Encoding queries
# 2024-10-01 15:16:30,039 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:03<00:00,  3.06it/s]
# 2024-10-01 15:16:33,326 - default - INFO - Encoding documents
# 2024-10-01 15:16:33,327 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:52<00:00,  5.27s/it]
# 2024-10-01 15:17:26,078 - default - INFO - Index 9344 documents
# 2024-10-01 15:17:26,088 - default - INFO - Total documents indexed: 9344
# 2024-10-01 15:17:28,032 - default - INFO - Evaluating model with k=10
# 2024-10-01 15:17:28,156 - default - INFO - Average Precision@10: 0.08154965753424659
# 2024-10-01 15:17:28,157 - default - INFO - Average MRR: 0.6535293423162643
# 2024-10-01 15:17:28,159 - default - INFO - Average NDCG@10: 0.6925187331943662
# 2024-10-01 15:17:28,161 - default - INFO - Loading checkpoint at 5 epoch
# 2024-10-01 15:17:28,163 - default - INFO - Loading checkpoint checkpoint_epoch_5.pth
# 2024-10-01 15:17:57,749 - default - INFO - Evaluating model with k=10
# 2024-10-01 15:17:57,752 - default - INFO - Encoding queries
# 2024-10-01 15:17:57,754 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:03<00:00,  3.23it/s]
# 2024-10-01 15:18:00,864 - default - INFO - Encoding documents
# 2024-10-01 15:18:00,866 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:52<00:00,  5.27s/it]
# 2024-10-01 15:18:53,613 - default - INFO - Index 9344 documents
# 2024-10-01 15:18:53,624 - default - INFO - Total documents indexed: 9344
# 2024-10-01 15:18:55,587 - default - INFO - Evaluating model with k=10
# 2024-10-01 15:18:55,712 - default - INFO - Average Precision@10: 0.08233090753424659
# 2024-10-01 15:18:55,714 - default - INFO - Average MRR: 0.7008142055338117
# 2024-10-01 15:18:55,715 - default - INFO - Average NDCG@10: 0.7304231267979384
# 2024-10-01 15:18:55,718 - default - INFO - Loading checkpoint at 6 epoch
# 2024-10-01 15:18:55,720 - default - INFO - Loading checkpoint checkpoint_epoch_6.pth
# 2024-10-01 15:19:27,915 - default - INFO - Evaluating model with k=10
# 2024-10-01 15:19:27,917 - default - INFO - Encoding queries
# 2024-10-01 15:19:27,919 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:03<00:00,  3.07it/s]
# 2024-10-01 15:19:31,190 - default - INFO - Encoding documents
# 2024-10-01 15:19:31,192 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:52<00:00,  5.27s/it]
# 2024-10-01 15:20:23,950 - default - INFO - Index 9344 documents
# 2024-10-01 15:20:23,961 - default - INFO - Total documents indexed: 9344
# 2024-10-01 15:20:25,908 - default - INFO - Evaluating model with k=10
# 2024-10-01 15:20:26,034 - default - INFO - Average Precision@10: 0.08195633561643836
# 2024-10-01 15:20:26,037 - default - INFO - Average MRR: 0.6803304726570994
# 2024-10-01 15:20:26,038 - default - INFO - Average NDCG@10: 0.7139547947111254
# 2024-10-01 15:20:26,040 - default - INFO - Loading checkpoint at 7 epoch
# 2024-10-01 15:20:26,042 - default - INFO - Loading checkpoint checkpoint_epoch_7.pth
# 2024-10-01 15:21:44,621 - default - INFO - Evaluating model with k=10
# 2024-10-01 15:21:44,623 - default - INFO - Encoding queries
# 2024-10-01 15:21:44,625 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:03<00:00,  3.24it/s]
# 2024-10-01 15:21:47,729 - default - INFO - Encoding documents
# 2024-10-01 15:21:47,730 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:52<00:00,  5.27s/it]
# 2024-10-01 15:22:40,491 - default - INFO - Index 9344 documents
# 2024-10-01 15:22:40,501 - default - INFO - Total documents indexed: 9344
# 2024-10-01 15:22:42,441 - default - INFO - Evaluating model with k=10
# 2024-10-01 15:22:42,567 - default - INFO - Average Precision@10: 0.08237371575342466
# 2024-10-01 15:22:42,568 - default - INFO - Average MRR: 0.6864568044683627
# 2024-10-01 15:22:42,570 - default - INFO - Average NDCG@10: 0.7195205002644087
# 2024-10-01 15:22:42,571 - default - INFO - Loading checkpoint at 8 epoch
# 2024-10-01 15:22:42,574 - default - INFO - Loading checkpoint checkpoint_epoch_8.pth
# 2024-10-01 15:23:56,478 - default - INFO - Evaluating model with k=10
# 2024-10-01 15:23:56,480 - default - INFO - Encoding queries
# 2024-10-01 15:23:56,483 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:03<00:00,  3.20it/s]
# 2024-10-01 15:23:59,619 - default - INFO - Encoding documents
# 2024-10-01 15:23:59,621 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:52<00:00,  5.30s/it]
# 2024-10-01 15:24:52,631 - default - INFO - Index 9344 documents
# 2024-10-01 15:24:52,641 - default - INFO - Total documents indexed: 9344
# 2024-10-01 15:24:54,596 - default - INFO - Evaluating model with k=10
# 2024-10-01 15:24:54,720 - default - INFO - Average Precision@10: 0.08239511986301369
# 2024-10-01 15:24:54,722 - default - INFO - Average MRR: 0.6976098319607524
# 2024-10-01 15:24:54,723 - default - INFO - Average NDCG@10: 0.7281032411805259
# 2024-10-01 15:24:54,725 - default - INFO - Loading checkpoint at 9 epoch
# 2024-10-01 15:24:54,728 - default - INFO - Loading checkpoint checkpoint_epoch_9.pth
# 2024-10-01 15:25:10,851 - default - INFO - Evaluating model with k=10
# 2024-10-01 15:25:10,853 - default - INFO - Encoding queries
# 2024-10-01 15:25:10,854 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:03<00:00,  3.25it/s]
# 2024-10-01 15:25:13,952 - default - INFO - Encoding documents
# 2024-10-01 15:25:13,954 - default - INFO - Encode 9344 texts to their embeddings
# Encoding batches: 100%|██████████| 10/10 [00:52<00:00,  5.28s/it]
# 2024-10-01 15:26:06,758 - default - INFO - Index 9344 documents
# 2024-10-01 15:26:06,768 - default - INFO - Total documents indexed: 9344
# 2024-10-01 15:26:08,738 - default - INFO - Evaluating model with k=10
# 2024-10-01 15:26:08,865 - default - INFO - Average Precision@10: 0.08217037671232877
# 2024-10-01 15:26:08,867 - default - INFO - Average MRR: 0.6948312472820178
# 2024-10-01 15:26:08,869 - default - INFO - Average NDCG@10: 0.7253659796873694
# CPU times: user 11min 5s, sys: 27.9 s, total: 11min 33s
# Wall time: 16min 20s
