# %%
import numpy as np
import pandas as pd
import os
import sys
from pathlib import Path

# %%
work_dir = '/home/nlp/achimoa/workspace/hebrew_text_retrieval/'
os.chdir(work_dir)

src_dir = os.path.join(work_dir, 'src')
if sys.path[0] not in src_dir:
    sys.path.insert(0, src_dir)

# %%
split = 'train'  # Change to 'validation' if needed
df_queries = pd.read_csv(f'outputs/translation/rajpurkar_squad_v2/{split}/gemini-2.0-flash-lite/queries_translated.csv')
df_documents = pd.read_csv(f'outputs/translation/rajpurkar_squad_v2/{split}/gemini-2.0-flash-lite/documents_translated.csv')

# %%
print(list(df_queries.keys()))
print(df_queries.shape)
print(list(df_documents.keys()))
print(df_documents.shape)
# Out:
# ['id', 'title', 'context', 'question', 'answers', 'context_hash', 'text', 'context_id', 'context_text', 'dataset_name', 'tokenizer', 'text_key', 'translation_key', 'context_key', 'translation_query_key', 'translation_document_key', 'system_prompt', 'user_prompt', 'prompt_prefix', 'prompt_file_name', 'translation', 'input_tokens', 'output_tokens', 'model_name', 'model_time', 'translation_time', 'timestamp', 'batch_idx', 'batch_size', 'batch_datetime', 'translation_datetime']
# (130319, 31)
# ['id', 'title', 'context', 'question', 'answers', 'context_hash', 'text', 'segment_id', 'segment_text', 'dataset_name', 'tokenizer', 'text_key', 'translation_key', 'context_key', 'translation_query_key', 'translation_document_key', 'system_prompt', 'user_prompt', 'prompt_prefix', 'prompt_file_name', 'translation', 'input_tokens', 'output_tokens', 'model_name', 'model_time', 'translation_time', 'timestamp', 'batch_idx', 'batch_size', 'batch_datetime', 'translation_datetime']
# (19029, 31)

# %%
# Get the set of GUIDs from df_documents
document_guids = set(df_documents['context_hash'])

# Check which df_queries['guid'] values exist in df_documents
mask = df_queries['context_hash'].isin(document_guids)

# Count the number of matching records
matching_count = mask.sum()

print(f"Number of matching GUIDs: {matching_count}")
# Out:
# Number of matching GUIDs: 130319

# %%
df_documents[['translation']].head()
# Out:
#                                          translation
# 0  ביונסה ג'יזל נואלס-קרטר (/biːˈjɒnseɪ/ bee-YON-...
# 1  בעקבות התפרקות דסטיניז צ'יילד ביוני 2005, היא ...
# 2  ביונסה, המתארת את עצמה כ"פמיניסטית מודרנית", י...
# 3  ביונסה ג'יזל נואלס נולדה ביוסטון, טקסס, ל-Cele...
# 4  ביונסה למדה בבית הספר היסודי סנט מרי בפדרסבורג...

# %%
df_documents[['id', 'context_hash', 'text', 'segment_id']]
# Out:
#                                      id                      context_hash  \
# 0      5566f9c0998385b8a8a2c94aa64aa980  5566f9c0998385b8a8a2c94aa64aa980
# 1      aad018fe3b6d1cb98a948e676d7c8036  aad018fe3b6d1cb98a948e676d7c8036
# 2      0b6ba39a81e6060caf33482bb8f79117  0b6ba39a81e6060caf33482bb8f79117
# 3      9416bece77bd0d876cb5ac8df8bd4ad5  9416bece77bd0d876cb5ac8df8bd4ad5
# 4      1a11be03640af35d4723f569f9d42dbf  1a11be03640af35d4723f569f9d42dbf
# ...                                 ...                               ...
# 19024  79bd2dfb9624397f5730d992d7007549  79bd2dfb9624397f5730d992d7007549
# 19025  2e90d7f5f88b129c1900db260468da11  2e90d7f5f88b129c1900db260468da11
# 19026  3775c0b780f8891a77976ebcfc4e3b7d  3775c0b780f8891a77976ebcfc4e3b7d
# 19027  57dabe0131de7aed80e210cafc7c1380  57dabe0131de7aed80e210cafc7c1380
# 19028  3c00aeb562abcce6579c29563ff8018d  3c00aeb562abcce6579c29563ff8018d
#
#                                                     text  segment_id
# 0      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...           0
# 1      Following the disbandment of Destiny's Child i...           0
# 2      A self-described "modern-day feminist", Beyonc...           0
# 3      Beyoncé Giselle Knowles was born in Houston, T...           0
# 4      Beyoncé attended St. Mary's Elementary School ...           0
# ...                                                  ...         ...
# 19024  Isaac Newton (1643–1727) inherited Descartes' ...           0
# 19025  There is an entire literature concerning the "...           0
# 19026  In the late 19th century with the discovery of...           0
# 19027  These quarks and leptons interact through four...           0
# 19028  The term "matter" is used throughout physics i...           0
#
# [19029 rows x 4 columns]

# %%
df_documents2 = df_documents.groupby(['id', 'context_hash', 'text'], as_index=False).agg({
    'translation': lambda texts: ' '.join([str(t) for t in texts])
})

# Step 2: Rename columns as needed
df_documents2 = df_documents2.rename(columns={
    'text': 'context_english',
    'translation': 'context_hebrew'
})

df_documents2['_source'] = 'rajpurkar_squad_v2'
print(df_documents2.columns)

# Step 3: Select required columns
df_documents2 = df_documents2[['id', 'context_hash', 'context_english', 'context_hebrew', '_source']]

# Step 4: Save the DataFrame to a JSON file
output_file = f'data/squad_v2/{split}/documents.jsonl'
Path(output_file).parent.mkdir(parents=True, exist_ok=True)
df_documents2.to_json(output_file, orient='records', lines=True, force_ascii=False)
# Out:
# Index(['id', 'context_hash', 'context_english', 'context_hebrew', '_source'], dtype='object')

# %%
df_documents2.head(100)
# Out:
#                                   id                      context_hash  \
# 0   000038abe02149e4abc7537083844eae  000038abe02149e4abc7537083844eae
# 1   00030ca16729eadf67fe4c79aeef7664  00030ca16729eadf67fe4c79aeef7664
# 2   0003afaccf271bd7a18d896314c531ce  0003afaccf271bd7a18d896314c531ce
# 3   000a6d9d751f7e955046e4c09efb2fbb  000a6d9d751f7e955046e4c09efb2fbb
# 4   0011fa1930606bf608665430563fa017  0011fa1930606bf608665430563fa017
# ..                               ...                               ...
# 95  015926d7c589bddf6af8362fc6e524c0  015926d7c589bddf6af8362fc6e524c0
# 96  0159f0deefaec5678ec0d3dbed680304  0159f0deefaec5678ec0d3dbed680304
# 97  015a019a0db5344d017b18fea41dcb26  015a019a0db5344d017b18fea41dcb26
# 98  0160134abebe04f5b7c4d268a7ad87f2  0160134abebe04f5b7c4d268a7ad87f2
# 99  0160ff091532be0e00695ba8cf5dbfbb  0160ff091532be0e00695ba8cf5dbfbb
#
#                                       context_english  \
# 0   This period of renewed assertiveness came to a...
# 1   The interceptor aircraft (or simply intercepto...
# 2   On runways, green lights indicate the beginnin...
# 3   The light energy captured by chlorophyll a is ...
# 4   Chengdu Economic and Technological Development...
# ..                                                ...
# 95  Although there were a number of department sto...
# 96  Guests ascending to the 67th, 69th, and 70th l...
# 97  North Carolina provides a large range of recre...
# 98  The change is evident in the reports of influe...
# 99  The Gorals of southern Poland and northern Slo...
#
#                                        context_hebrew             _source
# 0   תקופה זו של תקיפות מחודשת הגיעה לסיומה הקטסטרו...  rajpurkar_squad_v2
# 1   מטוס יירוט (או בפשטות מיירט) הוא סוג של מטוס ק...  rajpurkar_squad_v2
# 2   על מסלולי המראה, אורות ירוקים מציינים את תחילת...  rajpurkar_squad_v2
# 3   אנרגיית האור הלוכדת על ידי כלורופיל a היא בתחי...  rajpurkar_squad_v2
# 4   אזור הפיתוח הכלכלי והטכנולוגי של צ'נגדו (בסיני...  rajpurkar_squad_v2
# ..                                                ...                 ...
# 95  למרות שהיו מספר חנויות כלבו באוסטרליה במשך רוב...  rajpurkar_squad_v2
# 96  אורחים העולים למפלסי התצפית ה-67, ה-69 וה-70 (...  rajpurkar_squad_v2
# 97  צפון קרוליינה מספקת מגוון רחב של פעילויות פנאי...  rajpurkar_squad_v2
# 98  השינוי ניכר בדיווחיהם של מטיילים בריטים משפיעי...  rajpurkar_squad_v2
# 99  הגורלים של דרום פולין וצפון סלובקיה ממוצא חלקי...  rajpurkar_squad_v2
#
# [100 rows x 5 columns]

# %%
df_documents2.shape
# Out:
# (19029, 5)

# %%
df_queries.head()
# Out:
#                          id    title  \
# 0  56be85543aeaaa14008c9063  Beyoncé
# 1  56be85543aeaaa14008c9065  Beyoncé
# 2  56be85543aeaaa14008c9066  Beyoncé
# 3  56bf6b0f3aeaaa14008c9601  Beyoncé
# 4  56bf6b0f3aeaaa14008c9602  Beyoncé
#
#                                              context  \
# 0  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 1  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 2  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 3  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 4  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
#
#                                             question  \
# 0           When did Beyonce start becoming popular?
# 1  What areas did Beyonce compete in when she was...
# 2  When did Beyonce leave Destiny's Child and bec...
# 3      In what city and state did Beyonce  grow up?
# 4         In which decade did Beyonce become famous?
#
#                                              answers  \
# 0  {'text': ['in the late 1990s'], 'answer_start'...
# 1  {'text': ['singing and dancing'], 'answer_star...
# 2          {'text': ['2003'], 'answer_start': [526]}
# 3  {'text': ['Houston, Texas'], 'answer_start': [...
# 4    {'text': ['late 1990s'], 'answer_start': [276]}
#
#                        context_hash  \
# 0  5566f9c0998385b8a8a2c94aa64aa980
# 1  5566f9c0998385b8a8a2c94aa64aa980
# 2  5566f9c0998385b8a8a2c94aa64aa980
# 3  5566f9c0998385b8a8a2c94aa64aa980
# 4  5566f9c0998385b8a8a2c94aa64aa980
#
#                                                 text  \
# 0           When did Beyonce start becoming popular?
# 1  What areas did Beyonce compete in when she was...
# 2  When did Beyonce leave Destiny's Child and bec...
# 3      In what city and state did Beyonce  grow up?
# 4         In which decade did Beyonce become famous?
#
#                          context_id  \
# 0  5566f9c0998385b8a8a2c94aa64aa980
# 1  5566f9c0998385b8a8a2c94aa64aa980
# 2  5566f9c0998385b8a8a2c94aa64aa980
# 3  5566f9c0998385b8a8a2c94aa64aa980
# 4  5566f9c0998385b8a8a2c94aa64aa980
#
#                                         context_text        dataset_name  ...  \
# 0  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  rajpurkar/squad_v2  ...
# 1  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  rajpurkar/squad_v2  ...
# 2  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  rajpurkar/squad_v2  ...
# 3  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  rajpurkar/squad_v2  ...
# 4  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  rajpurkar/squad_v2  ...
#
#   input_tokens output_tokens             model_name model_time  \
# 0        246.0          36.0  gemini-2.0-flash-lite   2.587168
# 1        251.0          46.0  gemini-2.0-flash-lite   2.492141
# 2        253.0          59.0  gemini-2.0-flash-lite   2.614930
# 3        251.0          40.0  gemini-2.0-flash-lite   2.492606
# 4        247.0          36.0  gemini-2.0-flash-lite   2.455187
#
#   translation_time                   timestamp batch_idx batch_size  \
# 0         2.587183  2025-07-08 13:24:52.976154         0          1
# 1         2.492155  2025-07-08 13:24:52.881498         1          1
# 2         2.614943  2025-07-08 13:24:53.082593         2          1
# 3         2.492623  2025-07-08 13:24:52.964039         3          1
# 4         2.455204  2025-07-08 13:24:52.928191         4          1
#
#                batch_datetime        translation_datetime
# 0  2025-07-08 13:24:50.388942  2025-07-08 13:24:52.976160
# 1  2025-07-08 13:24:50.389315  2025-07-08 13:24:52.881503
# 2  2025-07-08 13:24:50.467624  2025-07-08 13:24:53.082598
# 3  2025-07-08 13:24:50.471388  2025-07-08 13:24:52.964047
# 4  2025-07-08 13:24:50.472951  2025-07-08 13:24:52.928199
#
# [5 rows x 31 columns]

# %%
df_queries.columns
# Out:
# Index(['id', 'title', 'context', 'question', 'answers', 'context_hash', 'text',
#        'context_id', 'context_text', 'dataset_name', 'tokenizer',
#        'text_key', 'translation_key', 'context_key', 'translation_query_key',
#        'translation_document_key', 'system_prompt', 'user_prompt', 'prompt_prefix',
#        'prompt_file_name', 'translation', 'input_tokens', 'output_tokens',
#        'model_name', 'model_time', 'translation_time', 'timestamp',
#        'batch_idx', 'batch_size', 'batch_datetime', 'translation_datetime'],
#       dtype='object')

# %%
guid_to_context_hebrew = dict(zip(df_documents2['context_hash'], df_documents2['context_hebrew']))
guid_to_context_english = dict(zip(df_documents2['context_hash'], df_documents2['context_english']))

df_queries2 = df_queries.copy()
df_queries2 = df_queries2.rename(columns={
    'text': 'question_english', 
    'translation': 'question_hebrew'
})

df_queries2["context_english"] = df_queries2["context_id"].map(guid_to_context_english)
df_queries2["context_hebrew"] = df_queries2["context_id"].map(guid_to_context_hebrew)

df_queries2 = df_queries2[['id', 'context_id', 'question_english', 'question_hebrew', 'context_english', 'context_hebrew']]
df_queries2['_source'] = 'rajpurkar_squad_v2'
df_queries2.head()
# Out:
#                          id                        context_id  \
# 0  56be85543aeaaa14008c9063  5566f9c0998385b8a8a2c94aa64aa980
# 1  56be85543aeaaa14008c9065  5566f9c0998385b8a8a2c94aa64aa980
# 2  56be85543aeaaa14008c9066  5566f9c0998385b8a8a2c94aa64aa980
# 3  56bf6b0f3aeaaa14008c9601  5566f9c0998385b8a8a2c94aa64aa980
# 4  56bf6b0f3aeaaa14008c9602  5566f9c0998385b8a8a2c94aa64aa980
#
#                                     question_english  \
# 0           When did Beyonce start becoming popular?
# 1  What areas did Beyonce compete in when she was...
# 2  When did Beyonce leave Destiny's Child and bec...
# 3      In what city and state did Beyonce  grow up?
# 4         In which decade did Beyonce become famous?
#
#                                      question_hebrew  \
# 0                  מתי ביונסה התחילה להיות פופולרית?
# 1          באיזה תחומים ביונסה התחרתה כשהייתה צעירה?
# 2  מתי ביונסה עזבה את דסטיניז צ'יילד והפכה לזמרת ...
# 3                      באיזו עיר ומדינה גדלה ביונסה?
# 4                         באיזה עשור ביונסה התפרסמה?
#
#                                      context_english  \
# 0  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 1  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 2  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 3  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 4  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
#
#                                       context_hebrew             _source
# 0  ביונסה ג'יזל נואלס-קרטר (/biːˈjɒnseɪ/ bee-YON-...  rajpurkar_squad_v2
# 1  ביונסה ג'יזל נואלס-קרטר (/biːˈjɒnseɪ/ bee-YON-...  rajpurkar_squad_v2
# 2  ביונסה ג'יזל נואלס-קרטר (/biːˈjɒnseɪ/ bee-YON-...  rajpurkar_squad_v2
# 3  ביונסה ג'יזל נואלס-קרטר (/biːˈjɒnseɪ/ bee-YON-...  rajpurkar_squad_v2
# 4  ביונסה ג'יזל נואלס-קרטר (/biːˈjɒnseɪ/ bee-YON-...  rajpurkar_squad_v2

# %%
# Save the DataFrame to a JSON file
output_file = f'data/squad_v2/{split}/queries.jsonl'
Path(output_file).parent.mkdir(parents=True, exist_ok=True)
df_queries2.to_json(output_file, orient='records', lines=True, force_ascii=False)

# %%
output_file
# Out:
# 'data/squad_v2/train/queries.jsonl'

# %%
df_queries.head()
# Out:
#                          id    title  \
# 0  56be85543aeaaa14008c9063  Beyoncé
# 1  56be85543aeaaa14008c9065  Beyoncé
# 2  56be85543aeaaa14008c9066  Beyoncé
# 3  56bf6b0f3aeaaa14008c9601  Beyoncé
# 4  56bf6b0f3aeaaa14008c9602  Beyoncé
#
#                                              context  \
# 0  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 1  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 2  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 3  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 4  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
#
#                                             question  \
# 0           When did Beyonce start becoming popular?
# 1  What areas did Beyonce compete in when she was...
# 2  When did Beyonce leave Destiny's Child and bec...
# 3      In what city and state did Beyonce  grow up?
# 4         In which decade did Beyonce become famous?
#
#                                              answers  \
# 0  {'text': ['in the late 1990s'], 'answer_start'...
# 1  {'text': ['singing and dancing'], 'answer_star...
# 2          {'text': ['2003'], 'answer_start': [526]}
# 3  {'text': ['Houston, Texas'], 'answer_start': [...
# 4    {'text': ['late 1990s'], 'answer_start': [276]}
#
#                        context_hash  \
# 0  5566f9c0998385b8a8a2c94aa64aa980
# 1  5566f9c0998385b8a8a2c94aa64aa980
# 2  5566f9c0998385b8a8a2c94aa64aa980
# 3  5566f9c0998385b8a8a2c94aa64aa980
# 4  5566f9c0998385b8a8a2c94aa64aa980
#
#                                                 text  \
# 0           When did Beyonce start becoming popular?
# 1  What areas did Beyonce compete in when she was...
# 2  When did Beyonce leave Destiny's Child and bec...
# 3      In what city and state did Beyonce  grow up?
# 4         In which decade did Beyonce become famous?
#
#                          context_id  \
# 0  5566f9c0998385b8a8a2c94aa64aa980
# 1  5566f9c0998385b8a8a2c94aa64aa980
# 2  5566f9c0998385b8a8a2c94aa64aa980
# 3  5566f9c0998385b8a8a2c94aa64aa980
# 4  5566f9c0998385b8a8a2c94aa64aa980
#
#                                         context_text        dataset_name  ...  \
# 0  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  rajpurkar/squad_v2  ...
# 1  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  rajpurkar/squad_v2  ...
# 2  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  rajpurkar/squad_v2  ...
# 3  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  rajpurkar/squad_v2  ...
# 4  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  rajpurkar/squad_v2  ...
#
#   input_tokens output_tokens             model_name model_time  \
# 0        246.0          36.0  gemini-2.0-flash-lite   2.587168
# 1        251.0          46.0  gemini-2.0-flash-lite   2.492141
# 2        253.0          59.0  gemini-2.0-flash-lite   2.614930
# 3        251.0          40.0  gemini-2.0-flash-lite   2.492606
# 4        247.0          36.0  gemini-2.0-flash-lite   2.455187
#
#   translation_time                   timestamp batch_idx batch_size  \
# 0         2.587183  2025-07-08 13:24:52.976154         0          1
# 1         2.492155  2025-07-08 13:24:52.881498         1          1
# 2         2.614943  2025-07-08 13:24:53.082593         2          1
# 3         2.492623  2025-07-08 13:24:52.964039         3          1
# 4         2.455204  2025-07-08 13:24:52.928191         4          1
#
#                batch_datetime        translation_datetime
# 0  2025-07-08 13:24:50.388942  2025-07-08 13:24:52.976160
# 1  2025-07-08 13:24:50.389315  2025-07-08 13:24:52.881503
# 2  2025-07-08 13:24:50.467624  2025-07-08 13:24:53.082598
# 3  2025-07-08 13:24:50.471388  2025-07-08 13:24:52.964047
# 4  2025-07-08 13:24:50.472951  2025-07-08 13:24:52.928199
#
# [5 rows x 31 columns]

# %%
from tqdm import tqdm
from datasets import load_dataset

data_files = {
        "queries": {
            "test": f'data/retrieval/squad_v2/{split}/queries.jsonl'
        },
        "documents": {
            "test": f'data/retrieval/squad_v2/{split}/documents.jsonl'
        }
    }

query_text_field = "question_english"
query_context_field = "context_hebrew"
document_text_field = "context_hebrew"
document_source_field = "_source"
main_source = "documents.jsonl"

queries_dataset = load_dataset("json", data_files=data_files["queries"], split="test")
documents_dataset = load_dataset("json", data_files=data_files["documents"], split="test")

questions = [item[query_text_field] for item in tqdm(queries_dataset, desc="Loading queries")]
gold = [item[query_context_field] for item in tqdm(queries_dataset, desc="Loading gold documents")]  # list of lists

unique_contexts = set()
deduped_contexts = []
contexts0 = [item for item in tqdm(documents_dataset, desc="Loading documents")]
# Deduplicate contexts
contexts0.sort(key=lambda x: 0 if x[document_source_field] == main_source else 1)
for i, context in tqdm(enumerate(contexts0), desc="Deduplicating contexts"):
    if context["guid"] not in unique_contexts:
        unique_contexts.add(context["guid"])
        deduped_contexts.append(context)
contexts = [c[document_text_field] for c in deduped_contexts]
print(len(deduped_contexts), "unique contexts found.")

# Find how many gold contexts are in the documents
found_gold_contexts = [c for c in set(gold) if c in contexts]
print(f"Found {len(found_gold_contexts)} gold contexts in the documents ({len(set(gold))}).")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 19
#      16 document_source_field = "_source"
#      17 main_source = "documents.jsonl"
# ---> 19 queries_dataset = load_dataset("json", data_files=data_files["queries"], split="test")
#      20 documents_dataset = load_dataset("json", data_files=data_files["documents"], split="test")
#      22 questions = [item[query_text_field] for item in tqdm(queries_dataset, desc="Loading queries")]
#
# File ~/miniconda3/envs/htr/lib/python3.12/site-packages/datasets/load.py:2062, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2057 verification_mode = VerificationMode(
#    2058     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2059 )
#    2061 # Create a dataset builder
# -> 2062 builder_instance = load_dataset_builder(
#    2063     path=path,
#    2064     name=name,
#    2065     data_dir=data_dir,
#    2066     data_files=data_files,
#    2067     cache_dir=cache_dir,
#    2068     features=features,
#    2069     download_config=download_config,
#    2070     download_mode=download_mode,
#    2071     revision=revision,
#    2072     token=token,
#    2073     storage_options=storage_options,
#    2074     trust_remote_code=trust_remote_code,
#    2075     _require_default_config_name=name is None,
#    2076     **config_kwargs,
#    2077 )
#    2079 # Return iterable dataset in case of streaming
#    2080 if streaming:
#
# File ~/miniconda3/envs/htr/lib/python3.12/site-packages/datasets/load.py:1782, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, trust_remote_code, _require_default_config_name, **config_kwargs)
#    1780     download_config = download_config.copy() if download_config else DownloadConfig()
#    1781     download_config.storage_options.update(storage_options)
# -> 1782 dataset_module = dataset_module_factory(
#    1783     path,
#    1784     revision=revision,
#    1785     download_config=download_config,
#    1786     download_mode=download_mode,
#    1787     data_dir=data_dir,
#    1788     data_files=data_files,
#    1789     cache_dir=cache_dir,
#    1790     trust_remote_code=trust_remote_code,
#    1791     _require_default_config_name=_require_default_config_name,
#    1792     _require_custom_configs=bool(config_kwargs),
#    1793 )
#    1794 # Get dataset builder class from the processing script
#    1795 builder_kwargs = dataset_module.builder_kwargs
#
# File ~/miniconda3/envs/htr/lib/python3.12/site-packages/datasets/load.py:1497, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, cache_dir, trust_remote_code, _require_default_config_name, _require_custom_configs, **download_kwargs)
#    1474 # We have several ways to get a dataset builder:
#    1475 #
#    1476 # - if path is the name of a packaged dataset module
#    (...)   1488
#    1489 # Try packaged
#    1490 if path in _PACKAGED_DATASETS_MODULES:
#    1491     return PackagedDatasetModuleFactory(
#    1492         path,
#    1493         data_dir=data_dir,
#    1494         data_files=data_files,
#    1495         download_config=download_config,
#    1496         download_mode=download_mode,
# -> 1497     ).get_module()
#    1498 # Try locally
#    1499 elif path.endswith(filename):
#
# File ~/miniconda3/envs/htr/lib/python3.12/site-packages/datasets/load.py:913, in PackagedDatasetModuleFactory.get_module(self)
#     907 base_path = Path(self.data_dir or "").expanduser().resolve().as_posix()
#     908 patterns = (
#     909     sanitize_patterns(self.data_files)
#     910     if self.data_files is not None
#     911     else get_data_patterns(base_path, download_config=self.download_config)
#     912 )
# --> 913 data_files = DataFilesDict.from_patterns(
#     914     patterns,
#     915     download_config=self.download_config,
#     916     base_path=base_path,
#     917 )
#     919 module_path, hash = _PACKAGED_DATASETS_MODULES[self.name]
#     921 builder_kwargs = {
#     922     "data_files": data_files,
#     923     "dataset_name": self.name,
#     924 }
#
# File ~/miniconda3/envs/htr/lib/python3.12/site-packages/datasets/data_files.py:689, in DataFilesDict.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     684 out = cls()
#     685 for key, patterns_for_key in patterns.items():
#     686     out[key] = (
#     687         patterns_for_key
#     688         if isinstance(patterns_for_key, DataFilesList)
# --> 689         else DataFilesList.from_patterns(
#     690             patterns_for_key,
#     691             base_path=base_path,
#     692             allowed_extensions=allowed_extensions,
#     693             download_config=download_config,
#     694         )
#     695     )
#     696 return out
#
# File ~/miniconda3/envs/htr/lib/python3.12/site-packages/datasets/data_files.py:582, in DataFilesList.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     579 for pattern in patterns:
#     580     try:
#     581         data_files.extend(
# --> 582             resolve_pattern(
#     583                 pattern,
#     584                 base_path=base_path,
#     585                 allowed_extensions=allowed_extensions,
#     586                 download_config=download_config,
#     587             )
#     588         )
#     589     except FileNotFoundError:
#     590         if not has_magic(pattern):
#
# File ~/miniconda3/envs/htr/lib/python3.12/site-packages/datasets/data_files.py:383, in resolve_pattern(pattern, base_path, allowed_extensions, download_config)
#     381     if allowed_extensions is not None:
#     382         error_msg += f" with any supported extension {list(allowed_extensions)}"
# --> 383     raise FileNotFoundError(error_msg)
#     384 return out
#
# FileNotFoundError: Unable to find '/home/nlp/achimoa/workspace/hebrew_text_retrieval/data/retrieval/squad_v2/train/queries.jsonl'

# %%
data_files2 = {
        "queries": {
            "test": 'data/retrieval/squad_v2/validation/queries.jsonl'
        },
        "documents": {
            "test": 'data/retrieval/squad_v2/validation/documents2.jsonl'
        }
}    

queries_dataset2 = load_dataset("json", data_files=data_files2["queries"], split="test")
documents_dataset2 = load_dataset("json", data_files=data_files2["documents"], split="test")
len(set([item["context_hebrew"] for item in tqdm(documents_dataset2, desc="Loading documents") if item["text"] is not None]))
# Out:
# Loading documents: 100%|██████████| 276204/276204 [00:20<00:00, 13439.70it/s]
# 1205

# %%
documents_dataset2[125000]
# Out:
# {'id': None,
#  'context_hash': None,
#  'context_english': None,
#  'context_hebrew': None,
#  '_source': 'wikipedia_hebrew_AllOfNewHebrewWikipediaWithArticles-Oct29-2023.forgpt.jsonl',
#  'guid': 'ab2b029a96889c5149c7943a8e8452e5b206fcbaa2c401c5b8535f2d7f9c0c7e',
#  'text': 'טוקיו דום\nטוקיו דום\nטוקיו דום (ביפנית: <foreign>; בבורסה:9681) הוא אצטדיון בייסבול הממוקם ברובע בונקיו שבטוקיו. הוא מכיל כ-55,000 מושבים והוא אצטדיון הבייסבול המקורה הגדול בעולם.\nהאצטדיון נפתח ב-17 במרץ 1988. הוא נבנה באתר בו שכן ולודרום ואצטדיון "קורקואן". כמו קורקואן לפניו, האצטדיון מארח מדי שנה את Toei Superheroes, מופע גיבורי על עם מסורת ארוכת שנים.\nהטוקיו דום מכונה "הביצה הגדולה" או "הביצה הגדולה של טוקיו" הודות לצורת הכיפה של גג האצטדיון. הגג הוא קרום גמיש שצורתו נשמרת על ידי הפעלת לחץ אוויר מועט אך רציף מצדו הפנימי של האצטדיון.\nהטוקיו דום הוא ביתה של קבוצת הבייסבול יומיורו ג\'יינטס, אך הוא מארח גם אירועים אחרים: משחקי כדורסל, פוטבול, כדורגל, אירועי היאבקות מקצועית, אמנויות לחימה משולבות, קיקבוקסינג, ומרוצי Monster trucks. באצטדיון נערכות גם הופעות מוזיקליות גדולות.\nהטוקיו דום הוא מושבו של היכל התהילה של הבייסבול ביפן, המסקר את ההיסטוריה ואת השחקנים הטובים ביותר בבייסבול היפני מאז ומעולם.\nעיר הטוקיו דום\nערך מורחב – עיר הטוקיו דום\nהאצטדיון הוא חלק מקומפלקס, הנקרא עיר הטוקיו דום, בו נכללים מרכז בידור הכולל גם מרכז לייף סטייל (ספא, חדר כושר, קניון), פארק שעשועים, בית מלון, אולם אירועים ותחנת רכבת תחתית. הקומפלקס כולו מושך למעלה מ-30 מיליון מבקרים בשנה.\nאירועים\nהטוקיו דום הוא אצטדיון ההופעות הגדול ביפן. ההופעה הראשונה שנערכה בו הייתה ב-19 במרץ 1988, בידי ההרכב The Alfee שהופיע עם תזמורת צבאית בינלאומית, שכללה נגנים מכל רחבי העולם[1].\nהופעות בולטות\nבמהלך השנים הופיעו באצטדיון אמנים רבים ביניהם מייקל ג\'קסון (21 הופעות, יותר מכל אמן או להקה אחרת), Guns N\' Roses, מריה קארי, ג\'נט ג\'קסון, טיילור סוויפט, להקת ההבי מטאל, X Japan, \u200fYellow Magic Orchestra ואחרים.\nהאצטדיון אירח את קונצרט הצדקה היפני בסדרת ה-"Human Rights Now!" של אמנסטי אינטרנשיונל, ב-27 בספטמבר 1988. הקונצרט הונחה בידי סטינג ופיטר גבריאל, וכלל הופעות של ברוס ספרינגסטין וה-E Street Band, טרייסי צ\'פמן ויוסו נ\'דור.\nבשנת 1992 באצטדיון נערכה הופעה של נאגאבוצ\'י צויושי בנוכחות 62 אלף צופים. שיא זה נשבר רק בשנת 2007.\nבפברואר 1992, להקת Guns N\' Roses מכרה את כל הכרטיסים לשלוש הופעות בטוקיו דום, כחלק מסיבוב ההופעות שלהם, "Use Your Illusion". אחת מההופעות אף שוחררה כ-DVD ב-2 חלקים. ב-19 בדצמבר 2009, הופיעה הלהקה בטוקיו דום בהרכבה החדש, כחלק מסיבוב ה-"Chinese Democracy" שלהם. ההופעה שארכה 3 שעות ו-37 דקות הייתה ההופעה הארוכה ביותר שנוגנה אי פעם בטוקיו דום, וכן ההופעה הארוכה ביותר בהיסטוריה של הלהקה.\nהופעתו של Gackt בערב חג המולד ב-24 בדצמבר 2005, מחזיקה בשיא ההופעה היקרה בהיסטוריה של קונצרטים ביפן. המופע הוערך בעלות של 500 מיליון ין, שהם בערך 4,296,270 מיליון דולר. לקח שנתיים כדי לתכנן את ההופעה וחצי שנה של חזרות קדמו לה.\nבתרבות פופולרית\nבשירם "The Sounder" מהאלבום "G Sides", מתייחסים הגורילז לטוקיו דום, באמירתם "גורליז קורעים את הכיפה כמו זאת שבטוקיו".\nסצנה בספרו של בן מזריץ\', "אמריקנים מכוערים", כוללת משחק פוטבול בין שחקני נבחרת ליגת הקיסוס לבין נבחרת האול סטארס היפנית.\nבפרק 17 של סדרת האנימה Baki the Grappler, נחשף כי הזירה המחתרתית של תחרות ה"אדם החזק בעולם" ממוקמת בקומה תת-קרקעית מתחת לטוקיו דום.\nהטוקיו דום מופיע ב-"Love Addiction", וידאו קליפ הבכורה של קייצ\'ירו קויאמה, חברת להקת NEWS.',
#  '_file': 'AllOfNewHebrewWikipediaWithArticles-Oct29-2023.forgpt.jsonl',
#  '_row_number': 123796}

# %%
len(questions), len(gold), len(contexts)
# Out:
# (1156, 1156, 0)

# %%
queries_dataset[0]
# Out:
# {'id': '56ddde6b9a695914005b9629',
#  'context_id': '4792c0101c483fd5cb5191f0d39d4426',
#  'question_english': 'When were the Normans in Normandy?',
#  'question_hebrew': 'מתי הנורמנים היו בנורמנדי?',
#  'context_english': 'The Normans (Norman: Nourmands; French: Normands; Latin: Normanni) were the people who in the 10th and 11th centuries gave their name to Normandy, a region in France. They were descended from Norse ("Norman" comes from "Norseman") raiders and pirates from Denmark, Iceland and Norway who, under their leader Rollo, agreed to swear fealty to King Charles III of West Francia. Through generations of assimilation and mixing with the native Frankish and Roman-Gaulish populations, their descendants would gradually merge with the Carolingian-based cultures of West Francia. The distinct cultural and ethnic identity of the Normans emerged initially in the first half of the 10th century, and it continued to evolve over the succeeding centuries.',
#  'context_hebrew': 'הנורמנים (נורמנית: Nourmands; צרפתית: Normands; לטינית: Normanni) היו האנשים שבמאות ה-10 וה-11 נתנו את שמם לנורמנדי, אזור בצרפת. הם צאצאים של פשיטות ושודדי ים נורדים ("נורמני" מגיע מ"איש צפון") מדנמרק, איסלנד ונורבגיה, אשר, תחת הנהגתם של רולו, הסכימו להישבע אמונים למלך שארל השלישי של פרנקיה המערבית. דרך דורות של הטמעה וערבוב עם האוכלוסיות הפרנקיות והרומיות-גאליות המקומיות, צאצאיהם יתמזגו בהדרגה עם התרבויות מבוססות הקרולינגים של פרנקיה המערבית. הזהות התרבותית והאתנית המובהקת של הנורמנים הופיעה בתחילה במחצית הראשונה של המאה ה-10, והיא המשיכה להתפתח לאורך המאות הבאות.',
#  '_source': 'queries.jsonl',
#  'guid': 'f769f28b6d8c79c34908e082f496d7af4dc22460171930b9792006abaab47867',
#  'text': 'When were the Normans in Normandy?',
#  '_file': 'queries.jsonl',
#  '_row_number': 1}

# %%
unique_contexts
# Out:
# set()
